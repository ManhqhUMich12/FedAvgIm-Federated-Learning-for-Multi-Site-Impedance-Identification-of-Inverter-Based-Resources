# %%
# %run -i fl_scenario_d.py
# Out:
# Using device: cuda
# #TRAIN files: 9, #TEST files: 9
# TARGET_IBR: gfli1 | LOCAL_TL_SOURCE_IBR: gfli4
# TARGET_FRACTION: 0.06
# SEEDS: [42, 43, 44, 45, 46]
# [TRAIN] gfli1  X:(390, 4) Y:(390, 8)
# [TRAIN] gfli2  X:(330, 4) Y:(330, 8)
# [TRAIN] gfli3  X:(330, 4) Y:(330, 8)
# [TRAIN] gfli4  X:(100, 4) Y:(100, 8)
# [TRAIN] gfli5  X:(330, 4) Y:(330, 8)
# [TRAIN] gfli6  X:(220, 4) Y:(220, 8)
# [TRAIN] gfli7  X:(140, 4) Y:(140, 8)
# [TRAIN] gfli8  X:(180, 4) Y:(180, 8)
# [TRAIN] gfli9  X:(40, 4) Y:(40, 8)
# [TEST ] gfli1  X:(780, 4) Y:(780, 8)
# [TEST ] gfli2  X:(660, 4) Y:(660, 8)
# [TEST ] gfli3  X:(660, 4) Y:(660, 8)
# [TEST ] gfli4  X:(200, 4) Y:(200, 8)
# [TEST ] gfli5  X:(660, 4) Y:(660, 8)
# [TEST ] gfli6  X:(440, 4) Y:(440, 8)
# [TEST ] gfli7  X:(280, 4) Y:(280, 8)
# [TEST ] gfli8  X:(342, 4) Y:(342, 8)
# [TEST ] gfli9  X:(80, 4) Y:(80, 8)
# ALL_IBRS   : ['gfli1', 'gfli2', 'gfli3', 'gfli4', 'gfli5', 'gfli6', 'gfli7', 'gfli8', 'gfli9']
# ...

# %%
# %run -i plot_scenario_d.py
# Out:
# ===== Data efficiency (FIXED): limited target labels from FULL target set =====
# [k-shot] n=   12 ( 3.08%) | Final test MSE FL-TL=9.6514e-01, LocalTL=9.9010e-01 | Gap(test-train) FL-TL=9.4058e-01, LocalTL=8.8334e-01
# [   10%] n=   39 (10.00%) | Final test MSE FL-TL=3.2171e-01, LocalTL=3.5779e-01 | Gap(test-train) FL-TL=2.8039e-01, LocalTL=2.7112e-01
# [   25%] n=   98 (25.13%) | Final test MSE FL-TL=1.2844e-01, LocalTL=2.3875e-01 | Gap(test-train) FL-TL=7.3700e-02, LocalTL=1.0931e-01
# [   50%] n=  195 (50.00%) | Final test MSE FL-TL=1.1289e-01, LocalTL=2.0683e-01 | Gap(test-train) FL-TL=5.2448e-02, LocalTL=5.7155e-02
# [  100%] n=  390 (100.00%) | Final test MSE FL-TL=9.9181e-02, LocalTL=2.0421e-01 | Gap(test-train) FL-TL=4.4140e-02, LocalTL=3.3959e-02
