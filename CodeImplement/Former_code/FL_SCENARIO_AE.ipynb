# %%
# Cell 1 — Imports & global setup

import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import h5py
from scipy.io import loadmat
from sklearn.preprocessing import StandardScaler

import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader

import random

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 2 — User configuration: file paths & label key

# Key name for labels inside .mat/.h5
LABEL_KEY = "Y_Y"

# ============== Config (train + test) ==============
TRAIN_FILE_PATHS = [
    "gfli1_impedance_dataset.mat",
    "gfli2_impedance_dataset.mat",
    "gfli3_impedance_dataset.mat",
    "gfli4_impedance_dataset.mat",
    "gfli5_impedance_dataset.mat",
    "gfli6_impedance_dataset.mat",
    "gfli7_impedance_dataset.mat",
    "gfli8_impedance_dataset.mat",
    "gfli9_impedance_dataset.mat",
]

TEST_FILE_PATHS = [
    "gfli1_test_impedance_dataset_copy.mat",
    "gfli2_test_impedance_dataset.mat",
    "gfli3_test_impedance_dataset.mat",
    "gfli4_test_impedance_dataset.mat",
    "gfli5_test_impedance_dataset.mat",
    "gfli6_test_impedance_dataset.mat",
    "gfli7_test_impedance_dataset.mat",
    "gfli8_test_impedance_dataset.mat",
    "gfli9_test_impedance_dataset.mat",
]

print(f"#TRAIN files: {len(TRAIN_FILE_PATHS)}, #TEST files: {len(TEST_FILE_PATHS)}")
# Out:
# #TRAIN files: 9, #TEST files: 9

# %%
# Cell 3 — IO helpers

def _fix_shape(arr, expected_cols=None):
    """
    Ensure 2D shape. If expected_cols is given, transpose when needed.
    """
    arr = np.asarray(arr)
    if arr.ndim == 1:
        arr = arr.reshape(-1, 1)
    if expected_cols is not None:
        if arr.shape[1] != expected_cols and arr.shape[0] == expected_cols:
            arr = arr.T
    return arr


def _extract_from_h5(f, label_key="Y_Y"):
    """
    Try to extract X (4 cols) and Y (8 cols) from an h5py.File handle.
    Expected structure:
      /Dataset/X, /Dataset/Y_Y (or label_key)
    Fallbacks:
      /X, /Y_Y at root.
    """
    def get_node(g, key):
        return g[key] if key in g else None

    # 1) common path: group 'Dataset'
    g = get_node(f, "Dataset")
    if g is None:
        g = get_node(f, "dataset")

    if g is not None:
        X = _fix_shape(g["X"][()], expected_cols=4)
        Ysrc = g[label_key] if label_key in g else g.get("Y_Y")
        if Ysrc is None:
            raise KeyError("Neither label_key nor 'Y_Y' found under /Dataset")
        Y = _fix_shape(Ysrc[()], expected_cols=8)
        return X, Y

    # 2) fallback: variables at file root
    Xnode = get_node(f, "X")
    Ynode = get_node(f, label_key) or get_node(f, "Y_Y")
    if Xnode is None or Ynode is None:
        raise KeyError("Could not find X and Y in HDF5 file.")
    X = _fix_shape(Xnode[()], expected_cols=4)
    Y = _fix_shape(Ynode[()], expected_cols=8)
    return X, Y


def _extract_from_mat(d, label_key="Y_Y"):
    """
    Extract from dict returned by scipy.io.loadmat.
    Support:
      - struct Dataset with fields X, Y_Y (or label_key)
      - top-level X, Y_Y
    """
    d2 = {k: v for k, v in d.items() if not k.startswith("__")}

    # struct-like 'Dataset'
    if "Dataset" in d2:
        G = d2["Dataset"]
        if hasattr(G, "dtype") and G.dtype.names:
            fields = G.dtype.names

            def get_field(name):
                if name in fields:
                    val = G[name]
                    val = np.array(val).squeeze()
                    return val
                return None

            X = _fix_shape(get_field("X"), expected_cols=4)
            Yraw = get_field(label_key) if get_field(label_key) is not None else get_field("Y_Y")
            if Yraw is None:
                raise KeyError("Neither label_key nor 'Y_Y' found in Dataset struct.")
            Y = _fix_shape(Yraw, expected_cols=8)
            return X, Y

    # top-level
    X = d2.get("X", None)
    Y = d2.get(label_key, None) or d2.get("Y_Y", None)
    if X is None or Y is None:
        raise KeyError("Could not find X and Y in MAT file (top-level).")
    X = _fix_shape(X, expected_cols=4)
    Y = _fix_shape(Y, expected_cols=8)
    return X, Y


def load_dataset_mat(path, label_key="Y_Y"):
    """
    Load one .mat dataset and return a dict:
      {
        'X': (N,4),
        'Y': (N,8),
        'family': 'GFMI'|'GFLI',
        'ibr': <filename stem>,
        'is_test': True|False
      }
    """
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"File not found: {path}")

    lower = path.name.lower()
    family = "GFMI" if "gfmi" in lower else "GFLI"
    is_test = "_test_" in lower
    ibr = path.stem

    # Try HDF5 first
    try:
        with h5py.File(path, "r") as f:
            X, Y = _extract_from_h5(f, label_key=label_key)
            return {"X": X, "Y": Y, "family": family, "ibr": ibr, "is_test": is_test}
    except Exception as e_h5:
        try:
            d = loadmat(str(path))
            X, Y = _extract_from_mat(d, label_key=label_key)
            return {"X": X, "Y": Y, "family": family, "ibr": ibr, "is_test": is_test}
        except Exception as e_mat:
            raise Exception(f"Error loading {path}: h5py-> {e_h5}; loadmat-> {e_mat}")

# %%
# Cell 4 — Load TRAIN / TEST datasets

loaded_tr, missing_tr = [], []
for fp in TRAIN_FILE_PATHS:
    try:
        d = load_dataset_mat(fp, LABEL_KEY)
        print(f"[TRAIN] Loaded: {fp} -> X:{d['X'].shape}, Y:{d['Y'].shape}, family={d['family']}")
        loaded_tr.append((fp, d))
    except Exception as e:
        print(f"[TRAIN] Error loading {fp}: {e}")
        missing_tr.append((fp, str(e)))

loaded_te, missing_te = [], []
for fp in TEST_FILE_PATHS:
    try:
        d = load_dataset_mat(fp, LABEL_KEY)
        print(f"[TEST ] Loaded: {fp} -> X:{d['X'].shape}, Y:{d['Y'].shape}, family={d['family']}")
        loaded_te.append((fp, d))
    except Exception as e:
        print(f"[TEST ] Error loading {fp}: {e}")
        missing_te.append((fp, str(e)))

print(f"\nTotal TRAIN loaded: {len(loaded_tr)}, TEST loaded: {len(loaded_te)}")
# Out:
# [TRAIN] Loaded: gfli1_impedance_dataset.mat -> X:(390, 4), Y:(390, 8), family=GFLI
# [TRAIN] Loaded: gfli2_impedance_dataset.mat -> X:(330, 4), Y:(330, 8), family=GFLI
# [TRAIN] Loaded: gfli3_impedance_dataset.mat -> X:(330, 4), Y:(330, 8), family=GFLI
# [TRAIN] Loaded: gfli4_impedance_dataset.mat -> X:(100, 4), Y:(100, 8), family=GFLI
# [TRAIN] Loaded: gfli5_impedance_dataset.mat -> X:(330, 4), Y:(330, 8), family=GFLI
# [TRAIN] Loaded: gfli6_impedance_dataset.mat -> X:(220, 4), Y:(220, 8), family=GFLI
# [TRAIN] Loaded: gfli7_impedance_dataset.mat -> X:(140, 4), Y:(140, 8), family=GFLI
# [TRAIN] Loaded: gfli8_impedance_dataset.mat -> X:(180, 4), Y:(180, 8), family=GFLI
# [TRAIN] Loaded: gfli9_impedance_dataset.mat -> X:(40, 4), Y:(40, 8), family=GFLI
# [TEST ] Loaded: gfli1_test_impedance_dataset_copy.mat -> X:(48600, 4), Y:(48600, 8), family=GFLI
# [TEST ] Loaded: gfli2_test_impedance_dataset.mat -> X:(660, 4), Y:(660, 8), family=GFLI
# [TEST ] Loaded: gfli3_test_impedance_dataset.mat -> X:(660, 4), Y:(660, 8), family=GFLI
# [TEST ] Loaded: gfli4_test_impedance_dataset.mat -> X:(200, 4), Y:(200, 8), family=GFLI
# [TEST ] Loaded: gfli5_test_impedance_dataset.mat -> X:(660, 4), Y:(660, 8), family=GFLI
# [TEST ] Loaded: gfli6_test_impedance_dataset.mat -> X:(440, 4), Y:(440, 8), family=GFLI
# [TEST ] Loaded: gfli7_test_impedance_dataset.mat -> X:(280, 4), Y:(280, 8), family=GFLI
# [TEST ] Loaded: gfli8_test_impedance_dataset.mat -> X:(342, 4), Y:(342, 8), family=GFLI
# [TEST ] Loaded: gfli9_test_impedance_dataset.mat -> X:(80, 4), Y:(80, 8), family=GFLI
#
# Total TRAIN loaded: 9, TEST loaded: 9

# %%
# Cell 5 — Scaling & clients

# Gom TRAIN theo family
X_tr_gfmi, Y_tr_gfmi = [], []
X_tr_gfli, Y_tr_gfli = [], []

for fp, d in loaded_tr:
    if d["family"] == "GFMI":
        X_tr_gfmi.append(d["X"])
        Y_tr_gfmi.append(d["Y"])
    elif d["family"] == "GFLI":
        X_tr_gfli.append(d["X"])
        Y_tr_gfli.append(d["Y"])

if not X_tr_gfli:
    raise RuntimeError("Need at least one GFLI dataset in loaded_tr.")

# Stack toàn bộ GFLI để fit scaler
X_tr_gfli_all = np.vstack(X_tr_gfli)
Y_tr_gfli_all = np.vstack(Y_tr_gfli)

# Nếu có GFMI thì vẫn xử lý được
if X_tr_gfmi:
    X_tr_gfmi_all = np.vstack(X_tr_gfmi)
    Y_tr_gfmi_all = np.vstack(Y_tr_gfmi)
    X_scaler_gfmi = StandardScaler().fit(X_tr_gfmi_all)
    Y_scaler_gfmi = StandardScaler().fit(Y_tr_gfmi_all)
else:
    X_scaler_gfmi = None
    Y_scaler_gfmi = None

# Scaler cho group GFLI (đang dùng chính cho FL)
X_scaler_gfli = StandardScaler().fit(X_tr_gfli_all)
Y_scaler_gfli = StandardScaler().fit(Y_tr_gfli_all)

# Input/output dim lấy từ GFLI
input_dim  = X_tr_gfli_all.shape[1]  # 4
output_dim = Y_tr_gfli_all.shape[1]  # 8
print("Input dim:", input_dim, "| Output dim:", output_dim)

# --------- Build clients ---------
clients_gfmi = []
clients_gfli = []
cid = 0

# GFMI clients (hiện tại có thể không có)
for fp, d in loaded_tr:
    fam = d["family"]
    X_raw = d["X"]
    Y_raw = d["Y"]

    if fam == "GFMI" and X_scaler_gfmi is not None:
        X_scaled = X_scaler_gfmi.transform(X_raw)
        Y_scaled = Y_scaler_gfmi.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32))
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32))
        ds = TensorDataset(X_t, Y_t)
        clients_gfmi.append({
            "id": cid,
            "name": Path(fp).stem,
            "family": fam,
            "dataset": ds,
            "n": X_t.shape[0],
        })
        cid += 1

# GFLI clients (client chính dùng cho FL)
for fp, d in loaded_tr:
    fam = d["family"]
    X_raw = d["X"]
    Y_raw = d["Y"]

    if fam == "GFLI":
        X_scaled = X_scaler_gfli.transform(X_raw)
        Y_scaled = Y_scaler_gfli.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32))
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32))
        ds = TensorDataset(X_t, Y_t)
        clients_gfli.append({
            "id": cid,
            "name": Path(fp).stem,
            "family": fam,
            "dataset": ds,
            "n": X_t.shape[0],
        })
        cid += 1

print("\nGFMI clients:")
for c in clients_gfmi:
    print(f"  id={c['id']}, name={c['name']}, n={c['n']}")

print("\nGFLI clients:")
for c in clients_gfli:
    print(f"  id={c['id']}, name={c['name']}, n={c['n']}")

# --------- Build TEST sets (scaled theo scaler group) ---------
test_sets_gfmi = []
test_sets_gfli = []

for fp, d in loaded_te:
    fam = d["family"]
    X_raw = d["X"]
    Y_raw = d["Y"]

    if fam == "GFMI" and X_scaler_gfmi is not None:
        X_scaled = X_scaler_gfmi.transform(X_raw)
        Y_scaled = Y_scaler_gfmi.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32)).to(device)
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32)).to(device)
        test_sets_gfmi.append({
            "name": Path(fp).stem,
            "family": fam,
            "ibr": d["ibr"],
            "X": X_t,
            "Y": Y_t,
            "n": X_t.shape[0],
        })
    elif fam == "GFLI":
        X_scaled = X_scaler_gfli.transform(X_raw)
        Y_scaled = Y_scaler_gfli.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32)).to(device)
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32)).to(device)
        test_sets_gfli.append({
            "name": Path(fp).stem,
            "family": fam,
            "ibr": d["ibr"],
            "X": X_t,
            "Y": Y_t,
            "n": X_t.shape[0],
        })

print(f"\n#TEST GFMI: {len(test_sets_gfmi)}, #TEST GFLI: {len(test_sets_gfli)}")
# Out:
# Input dim: 4 | Output dim: 8
#
# GFMI clients:
#
# GFLI clients:
#   id=0, name=gfli1_impedance_dataset, n=390
#   id=1, name=gfli2_impedance_dataset, n=330
#   id=2, name=gfli3_impedance_dataset, n=330
#   id=3, name=gfli4_impedance_dataset, n=100
#   id=4, name=gfli5_impedance_dataset, n=330
#   id=5, name=gfli6_impedance_dataset, n=220
#   id=6, name=gfli7_impedance_dataset, n=140
#   id=7, name=gfli8_impedance_dataset, n=180
#   id=8, name=gfli9_impedance_dataset, n=40
#
# #TEST GFMI: 0, #TEST GFLI: 9

# %%
# Cell 6 — Model definitions (trunk + head)

class Trunk(nn.Module):
    def __init__(self, in_dim=4, hidden_dim=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)


class Head(nn.Module):
    def __init__(self, hidden_dim=64, out_dim=8):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(hidden_dim, 16),
            nn.ReLU(),
            nn.Linear(16, out_dim),
        )

    def forward(self, h):
        return self.net(h)


class FullModel(nn.Module):
    def __init__(self, trunk: Trunk, head: Head):
        super().__init__()
        self.trunk = trunk
        self.head = head

    def forward(self, x):
        h = self.trunk(x)
        y = self.head(h)
        return y


HIDDEN_GFLI = 32

# %%
# Cell 7 — Standard FedAvg

ROUNDS_FL       = 200   # số round FL
LOCAL_EPOCHS_FL = 4
BATCH_SIZE_FL   = 512

LR_INIT_FL   = 1e-3
LR_DECAY1_FL = 700
LR_DECAY2_FL = 800
LR_FACTOR_FL = 0.1


def get_lr_for_round_fl(r: int) -> float:
    if r <= LR_DECAY1_FL:
        return LR_INIT_FL
    elif r <= LR_DECAY2_FL:
        return LR_INIT_FL * LR_FACTOR_FL
    else:
        return LR_INIT_FL * LR_FACTOR_FL * 0.5


def get_model_state_dict(model: FullModel):
    return {k: v.cpu().clone() for k, v in model.state_dict().items()}


def set_model_state_dict(model: FullModel, state_dict):
    model.load_state_dict(state_dict, strict=True)


def fedavg_models(model_states, sizes):
    total = float(sum(sizes))
    avg_state = {}
    for key in model_states[0].keys():
        avg_param = 0.0
        for sd, n in zip(model_states, sizes):
            avg_param += (n / total) * sd[key]
        avg_state[key] = avg_param
    return avg_state


def train_one_client_fullmodel(client,
                               global_model_state,
                               hidden_dim,
                               epochs=1,
                               batch_size=256,
                               lr=1e-3):
    trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
    head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
    model = FullModel(trunk, head).to(device)
    set_model_state_dict(model, global_model_state)
    model.train()

    ds = client["dataset"]
    loader = DataLoader(ds, batch_size=batch_size, shuffle=True)

    crit = nn.MSELoss()
    opt = torch.optim.Adam(model.parameters(), lr=lr)

    for _ in range(epochs):
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            y_pred = model(xb)
            loss = crit(y_pred, yb)
            loss.backward()
            opt.step()

    new_model_state = get_model_state_dict(model)
    return new_model_state


def evaluate_clients_full(global_model_state, clients, hidden_dim, batch_size=512):
    crit = nn.MSELoss()
    results = []

    for c in clients:
        trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
        head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
        model = FullModel(trunk, head).to(device)
        set_model_state_dict(model, global_model_state)
        model.eval()

        ds = c["dataset"]
        loader = DataLoader(ds, batch_size=batch_size, shuffle=False)

        total_loss, total_n = 0.0, 0
        with torch.no_grad():
            for xb, yb in loader:
                xb, yb = xb.to(device), yb.to(device)
                y_pred = model(xb)
                loss = crit(y_pred, yb) * xb.size(0)
                total_loss += loss.item()
                total_n += xb.size(0)

        mse = total_loss / total_n
        results.append((c["name"], mse))

    return results


def evaluate_tests_full(global_model_state, test_sets, hidden_dim, batch_size=512):
    crit = nn.MSELoss()
    results = []

    for ds in test_sets:
        test_name = ds["name"]

        trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
        head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
        model = FullModel(trunk, head).to(device)
        set_model_state_dict(model, global_model_state)
        model.eval()

        X_te = ds["X"]
        Y_te = ds["Y"]
        loader = DataLoader(TensorDataset(X_te, Y_te), batch_size=batch_size, shuffle=False)

        total_loss, total_n = 0.0, 0
        with torch.no_grad():
            for xb, yb in loader:
                xb, yb = xb.to(device), yb.to(device)
                y_pred = model(xb)
                loss = crit(y_pred, yb) * xb.size(0)
                total_loss += loss.item()
                total_n += xb.size(0)

        mse = total_loss / total_n
        results.append((test_name, mse))

    return results


def run_fedavg_full_gfli(clients, test_sets, hidden_dim, rounds):
    print(f"\n===== Standard FedAvg (full model) for GFLI (rounds={rounds}) =====")

    trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
    head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
    global_model = FullModel(trunk, head).to(device)
    global_model_state = get_model_state_dict(global_model)

    history = {
        "round": [],
        "train_mse_mean": [],
        "test_mse_mean": [],
        "train_mse_all": [],
        "test_mse_all": [],
    }

    for r in range(1, rounds + 1):
        model_states, sizes = [], []
        lr_round = get_lr_for_round_fl(r)

        for c in clients:
            new_state = train_one_client_fullmodel(
                client=c,
                global_model_state=global_model_state,
                hidden_dim=hidden_dim,
                epochs=LOCAL_EPOCHS_FL,
                batch_size=BATCH_SIZE_FL,
                lr=lr_round,
            )
            model_states.append(new_state)
            sizes.append(c["n"])

        global_model_state = fedavg_models(model_states, sizes)

        train_res = evaluate_clients_full(global_model_state, clients, hidden_dim)
        test_res  = evaluate_tests_full(global_model_state, test_sets, hidden_dim)

        train_mses = [m for _, m in train_res]
        test_mses  = [m for _, m in test_res] if test_res else []

        train_mse_mean = float(np.mean(train_mses))
        test_mse_mean  = float(np.mean(test_mses)) if test_mses else float("nan")

        history["round"].append(r)
        history["train_mse_mean"].append(train_mse_mean)
        history["test_mse_mean"].append(test_mse_mean)
        history["train_mse_all"].append(train_mses)
        history["test_mse_all"].append(test_mses)

        print(f"[FULL FedAvg] Round {r:03d} | "
              f"train MSE={train_mse_mean:.4e} | test MSE={test_mse_mean:.4e}")

    return global_model_state, history


# ---- Run FedAvg on GFLI clients ----
fullfedavg_model_state, history_fullfedavg = run_fedavg_full_gfli(
    clients=clients_gfli,
    test_sets=test_sets_gfli,
    hidden_dim=HIDDEN_GFLI,
    rounds=ROUNDS_FL,
)
# Out:
# ===== Standard FedAvg (full model) for GFLI (rounds=200) =====
# [FULL FedAvg] Round 001 | train MSE=1.0237e+00 | test MSE=1.0547e+00
# [FULL FedAvg] Round 002 | train MSE=1.0161e+00 | test MSE=1.0467e+00
# [FULL FedAvg] Round 003 | train MSE=1.0087e+00 | test MSE=1.0389e+00
# [FULL FedAvg] Round 004 | train MSE=1.0014e+00 | test MSE=1.0313e+00
# [FULL FedAvg] Round 005 | train MSE=9.9413e-01 | test MSE=1.0236e+00
# [FULL FedAvg] Round 006 | train MSE=9.8660e-01 | test MSE=1.0157e+00
# [FULL FedAvg] Round 007 | train MSE=9.7874e-01 | test MSE=1.0075e+00
# [FULL FedAvg] Round 008 | train MSE=9.7054e-01 | test MSE=9.9894e-01
# [FULL FedAvg] Round 009 | train MSE=9.6192e-01 | test MSE=9.9000e-01
# [FULL FedAvg] Round 010 | train MSE=9.5287e-01 | test MSE=9.8068e-01
# [FULL FedAvg] Round 011 | train MSE=9.4341e-01 | test MSE=9.7098e-01
# [FULL FedAvg] Round 012 | train MSE=9.3353e-01 | test MSE=9.6089e-01
# [FULL FedAvg] Round 013 | train MSE=9.2336e-01 | test MSE=9.5056e-01
# [FULL FedAvg] Round 014 | train MSE=9.1288e-01 | test MSE=9.3997e-01
# [FULL FedAvg] Round 015 | train MSE=9.0206e-01 | test MSE=9.2912e-01
# [FULL FedAvg] Round 016 | train MSE=8.9089e-01 | test MSE=9.1800e-01
# [FULL FedAvg] Round 017 | train MSE=8.7948e-01 | test MSE=9.0670e-01
# [FULL FedAvg] Round 018 | train MSE=8.6792e-01 | test MSE=8.9537e-01
# [FULL FedAvg] Round 019 | train MSE=8.5627e-01 | test MSE=8.8405e-01
# [FULL FedAvg] Round 020 | train MSE=8.4453e-01 | test MSE=8.7271e-01
# [FULL FedAvg] Round 021 | train MSE=8.3270e-01 | test MSE=8.6142e-01
# [FULL FedAvg] Round 022 | train MSE=8.2083e-01 | test MSE=8.5022e-01
# [FULL FedAvg] Round 023 | train MSE=8.0907e-01 | test MSE=8.3928e-01
# [FULL FedAvg] Round 024 | train MSE=7.9752e-01 | test MSE=8.2868e-01
# [FULL FedAvg] Round 025 | train MSE=7.8619e-01 | test MSE=8.1847e-01
# [FULL FedAvg] Round 026 | train MSE=7.7517e-01 | test MSE=8.0871e-01
# [FULL FedAvg] Round 027 | train MSE=7.6453e-01 | test MSE=7.9946e-01
# [FULL FedAvg] Round 028 | train MSE=7.5435e-01 | test MSE=7.9079e-01
# [FULL FedAvg] Round 029 | train MSE=7.4468e-01 | test MSE=7.8274e-01
# [FULL FedAvg] Round 030 | train MSE=7.3557e-01 | test MSE=7.7525e-01
# [FULL FedAvg] Round 031 | train MSE=7.2698e-01 | test MSE=7.6835e-01
# [FULL FedAvg] Round 032 | train MSE=7.1892e-01 | test MSE=7.6205e-01
# [FULL FedAvg] Round 033 | train MSE=7.1143e-01 | test MSE=7.5625e-01
# [FULL FedAvg] Round 034 | train MSE=7.0435e-01 | test MSE=7.5075e-01
# [FULL FedAvg] Round 035 | train MSE=6.9761e-01 | test MSE=7.4541e-01
# [FULL FedAvg] Round 036 | train MSE=6.9121e-01 | test MSE=7.4031e-01
# [FULL FedAvg] Round 037 | train MSE=6.8519e-01 | test MSE=7.3540e-01
# [FULL FedAvg] Round 038 | train MSE=6.7939e-01 | test MSE=7.3056e-01
# [FULL FedAvg] Round 039 | train MSE=6.7388e-01 | test MSE=7.2591e-01
# [FULL FedAvg] Round 040 | train MSE=6.6863e-01 | test MSE=7.2138e-01
# [FULL FedAvg] Round 041 | train MSE=6.6362e-01 | test MSE=7.1702e-01
# [FULL FedAvg] Round 042 | train MSE=6.5880e-01 | test MSE=7.1280e-01
# [FULL FedAvg] Round 043 | train MSE=6.5416e-01 | test MSE=7.0866e-01
# [FULL FedAvg] Round 044 | train MSE=6.4960e-01 | test MSE=7.0452e-01
# [FULL FedAvg] Round 045 | train MSE=6.4512e-01 | test MSE=7.0040e-01
# [FULL FedAvg] Round 046 | train MSE=6.4061e-01 | test MSE=6.9619e-01
# [FULL FedAvg] Round 047 | train MSE=6.3607e-01 | test MSE=6.9189e-01
# [FULL FedAvg] Round 048 | train MSE=6.3154e-01 | test MSE=6.8753e-01
# [FULL FedAvg] Round 049 | train MSE=6.2702e-01 | test MSE=6.8314e-01
# [FULL FedAvg] Round 050 | train MSE=6.2245e-01 | test MSE=6.7865e-01
# [FULL FedAvg] Round 051 | train MSE=6.1788e-01 | test MSE=6.7411e-01
# [FULL FedAvg] Round 052 | train MSE=6.1329e-01 | test MSE=6.6946e-01
# [FULL FedAvg] Round 053 | train MSE=6.0864e-01 | test MSE=6.6466e-01
# [FULL FedAvg] Round 054 | train MSE=6.0393e-01 | test MSE=6.5976e-01
# [FULL FedAvg] Round 055 | train MSE=5.9915e-01 | test MSE=6.5472e-01
# [FULL FedAvg] Round 056 | train MSE=5.9434e-01 | test MSE=6.4961e-01
# [FULL FedAvg] Round 057 | train MSE=5.8944e-01 | test MSE=6.4439e-01
# [FULL FedAvg] Round 058 | train MSE=5.8451e-01 | test MSE=6.3916e-01
# [FULL FedAvg] Round 059 | train MSE=5.7948e-01 | test MSE=6.3378e-01
# [FULL FedAvg] Round 060 | train MSE=5.7435e-01 | test MSE=6.2827e-01
# [FULL FedAvg] Round 061 | train MSE=5.6907e-01 | test MSE=6.2255e-01
# [FULL FedAvg] Round 062 | train MSE=5.6367e-01 | test MSE=6.1670e-01
# [FULL FedAvg] Round 063 | train MSE=5.5817e-01 | test MSE=6.1069e-01
# [FULL FedAvg] Round 064 | train MSE=5.5263e-01 | test MSE=6.0464e-01
# [FULL FedAvg] Round 065 | train MSE=5.4706e-01 | test MSE=5.9858e-01
# [FULL FedAvg] Round 066 | train MSE=5.4145e-01 | test MSE=5.9246e-01
# [FULL FedAvg] Round 067 | train MSE=5.3581e-01 | test MSE=5.8630e-01
# [FULL FedAvg] Round 068 | train MSE=5.3013e-01 | test MSE=5.8010e-01
# [FULL FedAvg] Round 069 | train MSE=5.2443e-01 | test MSE=5.7387e-01
# [FULL FedAvg] Round 070 | train MSE=5.1876e-01 | test MSE=5.6768e-01
# [FULL FedAvg] Round 071 | train MSE=5.1304e-01 | test MSE=5.6146e-01
# [FULL FedAvg] Round 072 | train MSE=5.0725e-01 | test MSE=5.5516e-01
# [FULL FedAvg] Round 073 | train MSE=5.0140e-01 | test MSE=5.4880e-01
# [FULL FedAvg] Round 074 | train MSE=4.9554e-01 | test MSE=5.4245e-01
# [FULL FedAvg] Round 075 | train MSE=4.8966e-01 | test MSE=5.3612e-01
# [FULL FedAvg] Round 076 | train MSE=4.8379e-01 | test MSE=5.2985e-01
# [FULL FedAvg] Round 077 | train MSE=4.7796e-01 | test MSE=5.2364e-01
# [FULL FedAvg] Round 078 | train MSE=4.7212e-01 | test MSE=5.1743e-01
# [FULL FedAvg] Round 079 | train MSE=4.6632e-01 | test MSE=5.1132e-01
# [FULL FedAvg] Round 080 | train MSE=4.6054e-01 | test MSE=5.0525e-01
# [FULL FedAvg] Round 081 | train MSE=4.5475e-01 | test MSE=4.9920e-01
# [FULL FedAvg] Round 082 | train MSE=4.4904e-01 | test MSE=4.9325e-01
# [FULL FedAvg] Round 083 | train MSE=4.4337e-01 | test MSE=4.8736e-01
# [FULL FedAvg] Round 084 | train MSE=4.3772e-01 | test MSE=4.8151e-01
# [FULL FedAvg] Round 085 | train MSE=4.3216e-01 | test MSE=4.7574e-01
# [FULL FedAvg] Round 086 | train MSE=4.2671e-01 | test MSE=4.7010e-01
# [FULL FedAvg] Round 087 | train MSE=4.2133e-01 | test MSE=4.6457e-01
# [FULL FedAvg] Round 088 | train MSE=4.1604e-01 | test MSE=4.5914e-01
# [FULL FedAvg] Round 089 | train MSE=4.1087e-01 | test MSE=4.5387e-01
# [FULL FedAvg] Round 090 | train MSE=4.0576e-01 | test MSE=4.4864e-01
# [FULL FedAvg] Round 091 | train MSE=4.0073e-01 | test MSE=4.4350e-01
# [FULL FedAvg] Round 092 | train MSE=3.9575e-01 | test MSE=4.3840e-01
# [FULL FedAvg] Round 093 | train MSE=3.9085e-01 | test MSE=4.3338e-01
# [FULL FedAvg] Round 094 | train MSE=3.8606e-01 | test MSE=4.2847e-01
# [FULL FedAvg] Round 095 | train MSE=3.8129e-01 | test MSE=4.2354e-01
# [FULL FedAvg] Round 096 | train MSE=3.7651e-01 | test MSE=4.1852e-01
# [FULL FedAvg] Round 097 | train MSE=3.7174e-01 | test MSE=4.1347e-01
# [FULL FedAvg] Round 098 | train MSE=3.6703e-01 | test MSE=4.0842e-01
# [FULL FedAvg] Round 099 | train MSE=3.6240e-01 | test MSE=4.0344e-01
# [FULL FedAvg] Round 100 | train MSE=3.5787e-01 | test MSE=3.9855e-01
# [FULL FedAvg] Round 101 | train MSE=3.5343e-01 | test MSE=3.9374e-01
# [FULL FedAvg] Round 102 | train MSE=3.4907e-01 | test MSE=3.8898e-01
# [FULL FedAvg] Round 103 | train MSE=3.4477e-01 | test MSE=3.8426e-01
# [FULL FedAvg] Round 104 | train MSE=3.4053e-01 | test MSE=3.7958e-01
# [FULL FedAvg] Round 105 | train MSE=3.3636e-01 | test MSE=3.7494e-01
# [FULL FedAvg] Round 106 | train MSE=3.3222e-01 | test MSE=3.7031e-01
# [FULL FedAvg] Round 107 | train MSE=3.2809e-01 | test MSE=3.6560e-01
# [FULL FedAvg] Round 108 | train MSE=3.2398e-01 | test MSE=3.6088e-01
# [FULL FedAvg] Round 109 | train MSE=3.1987e-01 | test MSE=3.5614e-01
# [FULL FedAvg] Round 110 | train MSE=3.1579e-01 | test MSE=3.5139e-01
# [FULL FedAvg] Round 111 | train MSE=3.1170e-01 | test MSE=3.4663e-01
# [FULL FedAvg] Round 112 | train MSE=3.0760e-01 | test MSE=3.4188e-01
# [FULL FedAvg] Round 113 | train MSE=3.0351e-01 | test MSE=3.3713e-01
# [FULL FedAvg] Round 114 | train MSE=2.9939e-01 | test MSE=3.3239e-01
# [FULL FedAvg] Round 115 | train MSE=2.9526e-01 | test MSE=3.2763e-01
# [FULL FedAvg] Round 116 | train MSE=2.9111e-01 | test MSE=3.2287e-01
# [FULL FedAvg] Round 117 | train MSE=2.8691e-01 | test MSE=3.1806e-01
# [FULL FedAvg] Round 118 | train MSE=2.8273e-01 | test MSE=3.1330e-01
# [FULL FedAvg] Round 119 | train MSE=2.7851e-01 | test MSE=3.0853e-01
# [FULL FedAvg] Round 120 | train MSE=2.7429e-01 | test MSE=3.0376e-01
# [FULL FedAvg] Round 121 | train MSE=2.7010e-01 | test MSE=2.9905e-01
# [FULL FedAvg] Round 122 | train MSE=2.6594e-01 | test MSE=2.9442e-01
# [FULL FedAvg] Round 123 | train MSE=2.6181e-01 | test MSE=2.8981e-01
# [FULL FedAvg] Round 124 | train MSE=2.5769e-01 | test MSE=2.8524e-01
# [FULL FedAvg] Round 125 | train MSE=2.5353e-01 | test MSE=2.8065e-01
# [FULL FedAvg] Round 126 | train MSE=2.4933e-01 | test MSE=2.7604e-01
# [FULL FedAvg] Round 127 | train MSE=2.4511e-01 | test MSE=2.7143e-01
# [FULL FedAvg] Round 128 | train MSE=2.4089e-01 | test MSE=2.6683e-01
# [FULL FedAvg] Round 129 | train MSE=2.3662e-01 | test MSE=2.6219e-01
# [FULL FedAvg] Round 130 | train MSE=2.3235e-01 | test MSE=2.5758e-01
# [FULL FedAvg] Round 131 | train MSE=2.2806e-01 | test MSE=2.5296e-01
# [FULL FedAvg] Round 132 | train MSE=2.2376e-01 | test MSE=2.4837e-01
# [FULL FedAvg] Round 133 | train MSE=2.1946e-01 | test MSE=2.4376e-01
# [FULL FedAvg] Round 134 | train MSE=2.1511e-01 | test MSE=2.3911e-01
# [FULL FedAvg] Round 135 | train MSE=2.1076e-01 | test MSE=2.3446e-01
# [FULL FedAvg] Round 136 | train MSE=2.0642e-01 | test MSE=2.2981e-01
# [FULL FedAvg] Round 137 | train MSE=2.0210e-01 | test MSE=2.2522e-01
# [FULL FedAvg] Round 138 | train MSE=1.9776e-01 | test MSE=2.2061e-01
# [FULL FedAvg] Round 139 | train MSE=1.9344e-01 | test MSE=2.1600e-01
# [FULL FedAvg] Round 140 | train MSE=1.8914e-01 | test MSE=2.1144e-01
# [FULL FedAvg] Round 141 | train MSE=1.8482e-01 | test MSE=2.0684e-01
# [FULL FedAvg] Round 142 | train MSE=1.8052e-01 | test MSE=2.0227e-01
# [FULL FedAvg] Round 143 | train MSE=1.7624e-01 | test MSE=1.9774e-01
# [FULL FedAvg] Round 144 | train MSE=1.7201e-01 | test MSE=1.9326e-01
# [FULL FedAvg] Round 145 | train MSE=1.6780e-01 | test MSE=1.8881e-01
# [FULL FedAvg] Round 146 | train MSE=1.6364e-01 | test MSE=1.8440e-01
# [FULL FedAvg] Round 147 | train MSE=1.5951e-01 | test MSE=1.8004e-01
# [FULL FedAvg] Round 148 | train MSE=1.5541e-01 | test MSE=1.7568e-01
# [FULL FedAvg] Round 149 | train MSE=1.5135e-01 | test MSE=1.7136e-01
# [FULL FedAvg] Round 150 | train MSE=1.4734e-01 | test MSE=1.6708e-01
# [FULL FedAvg] Round 151 | train MSE=1.4336e-01 | test MSE=1.6285e-01
# [FULL FedAvg] Round 152 | train MSE=1.3947e-01 | test MSE=1.5870e-01
# [FULL FedAvg] Round 153 | train MSE=1.3567e-01 | test MSE=1.5465e-01
# [FULL FedAvg] Round 154 | train MSE=1.3196e-01 | test MSE=1.5067e-01
# [FULL FedAvg] Round 155 | train MSE=1.2833e-01 | test MSE=1.4679e-01
# [FULL FedAvg] Round 156 | train MSE=1.2479e-01 | test MSE=1.4300e-01
# [FULL FedAvg] Round 157 | train MSE=1.2134e-01 | test MSE=1.3932e-01
# [FULL FedAvg] Round 158 | train MSE=1.1799e-01 | test MSE=1.3576e-01
# [FULL FedAvg] Round 159 | train MSE=1.1473e-01 | test MSE=1.3229e-01
# [FULL FedAvg] Round 160 | train MSE=1.1156e-01 | test MSE=1.2894e-01
# [FULL FedAvg] Round 161 | train MSE=1.0850e-01 | test MSE=1.2571e-01
# [FULL FedAvg] Round 162 | train MSE=1.0554e-01 | test MSE=1.2258e-01
# [FULL FedAvg] Round 163 | train MSE=1.0265e-01 | test MSE=1.1955e-01
# [FULL FedAvg] Round 164 | train MSE=9.9880e-02 | test MSE=1.1662e-01
# [FULL FedAvg] Round 165 | train MSE=9.7202e-02 | test MSE=1.1380e-01
# [FULL FedAvg] Round 166 | train MSE=9.4604e-02 | test MSE=1.1105e-01
# [FULL FedAvg] Round 167 | train MSE=9.2099e-02 | test MSE=1.0841e-01
# [FULL FedAvg] Round 168 | train MSE=8.9698e-02 | test MSE=1.0588e-01
# [FULL FedAvg] Round 169 | train MSE=8.7392e-02 | test MSE=1.0344e-01
# [FULL FedAvg] Round 170 | train MSE=8.5181e-02 | test MSE=1.0111e-01
# [FULL FedAvg] Round 171 | train MSE=8.3032e-02 | test MSE=9.8830e-02
# [FULL FedAvg] Round 172 | train MSE=8.0968e-02 | test MSE=9.6621e-02
# [FULL FedAvg] Round 173 | train MSE=7.8988e-02 | test MSE=9.4494e-02
# [FULL FedAvg] Round 174 | train MSE=7.7106e-02 | test MSE=9.2469e-02
# [FULL FedAvg] Round 175 | train MSE=7.5289e-02 | test MSE=9.0494e-02
# [FULL FedAvg] Round 176 | train MSE=7.3547e-02 | test MSE=8.8602e-02
# [FULL FedAvg] Round 177 | train MSE=7.1885e-02 | test MSE=8.6787e-02
# [FULL FedAvg] Round 178 | train MSE=7.0292e-02 | test MSE=8.5039e-02
# [FULL FedAvg] Round 179 | train MSE=6.8769e-02 | test MSE=8.3357e-02
# [FULL FedAvg] Round 180 | train MSE=6.7315e-02 | test MSE=8.1743e-02
# [FULL FedAvg] Round 181 | train MSE=6.5910e-02 | test MSE=8.0175e-02
# [FULL FedAvg] Round 182 | train MSE=6.4558e-02 | test MSE=7.8661e-02
# [FULL FedAvg] Round 183 | train MSE=6.3268e-02 | test MSE=7.7218e-02
# [FULL FedAvg] Round 184 | train MSE=6.2019e-02 | test MSE=7.5818e-02
# [FULL FedAvg] Round 185 | train MSE=6.0821e-02 | test MSE=7.4466e-02
# [FULL FedAvg] Round 186 | train MSE=5.9657e-02 | test MSE=7.3150e-02
# [FULL FedAvg] Round 187 | train MSE=5.8540e-02 | test MSE=7.1882e-02
# [FULL FedAvg] Round 188 | train MSE=5.7451e-02 | test MSE=7.0638e-02
# [FULL FedAvg] Round 189 | train MSE=5.6402e-02 | test MSE=6.9433e-02
# [FULL FedAvg] Round 190 | train MSE=5.5389e-02 | test MSE=6.8263e-02
# [FULL FedAvg] Round 191 | train MSE=5.4394e-02 | test MSE=6.7113e-02
# [FULL FedAvg] Round 192 | train MSE=5.3419e-02 | test MSE=6.5980e-02
# [FULL FedAvg] Round 193 | train MSE=5.2476e-02 | test MSE=6.4880e-02
# [FULL FedAvg] Round 194 | train MSE=5.1556e-02 | test MSE=6.3800e-02
# [FULL FedAvg] Round 195 | train MSE=5.0665e-02 | test MSE=6.2754e-02
# [FULL FedAvg] Round 196 | train MSE=4.9793e-02 | test MSE=6.1730e-02
# [FULL FedAvg] Round 197 | train MSE=4.8951e-02 | test MSE=6.0736e-02
# [FULL FedAvg] Round 198 | train MSE=4.8133e-02 | test MSE=5.9765e-02
# [FULL FedAvg] Round 199 | train MSE=4.7340e-02 | test MSE=5.8832e-02
# [FULL FedAvg] Round 200 | train MSE=4.6561e-02 | test MSE=5.7913e-02

# %%
# Cell 8 — Helpers: scale dataset & local FNN

def prepare_new_gfli_dataset(X_raw, Y_raw,
                             X_scaler=X_scaler_gfli,
                             Y_scaler=Y_scaler_gfli):
    """
    Scale dữ liệu GFLI bằng scaler chung,
    rồi convert sang TensorDataset dùng cho PyTorch.
    """
    X_scaled = X_scaler.transform(X_raw)
    Y_scaled = Y_scaler.transform(Y_raw)

    X_t = torch.from_numpy(X_scaled.astype(np.float32))
    Y_t = torch.from_numpy(Y_scaled.astype(np.float32))

    ds = TensorDataset(X_t, Y_t)
    return ds


def eval_mse_on_dataset(model, dataset, batch_size=512):
    model.eval()
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    crit = nn.MSELoss()  # mean

    total_loss, total_n = 0.0, 0
    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            y_pred = model(xb)
            loss = crit(y_pred, yb)
            total_loss += loss.item() * xb.size(0)
            total_n    += xb.size(0)

    return total_loss / total_n



def train_full_from_scratch_oneclient(ds_train, ds_test,
                                      epochs=100,
                                      batch_size=512,
                                      lr=1e-3,
                                      tag="FNN-local"):
    """
    FNN local: full model random init, chỉ học trên 1 IBR (train set),
    và evaluate trên test set.
    """
    trunk = Trunk(in_dim=input_dim, hidden_dim=HIDDEN_GFLI).to(device)
    head  = Head(hidden_dim=HIDDEN_GFLI, out_dim=output_dim).to(device)
    model = FullModel(trunk, head).to(device)

    crit = nn.MSELoss()
    opt  = torch.optim.Adam(model.parameters(), lr=lr)

    train_loader = DataLoader(ds_train, batch_size=batch_size, shuffle=True)
    test_loader  = DataLoader(ds_test,  batch_size=batch_size, shuffle=False)

    hist_train, hist_test = [], []

    for ep in range(1, epochs + 1):
        # ---- TRAIN ----
        model.train()
        tot_loss, tot_n = 0.0, 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            y_pred = model(xb)
            loss = crit(y_pred, yb)
            loss.backward()
            opt.step()
            tot_loss += loss.item() * xb.size(0)
            tot_n    += xb.size(0)
        train_mse = tot_loss / tot_n
        hist_train.append(train_mse)

        # TEST
        model.eval()
        tot_loss, tot_n = 0.0, 0
        with torch.no_grad():
            for xb, yb in test_loader:
                xb, yb = xb.to(device), yb.to(device)
                y_pred = model(xb)
                loss = crit(y_pred, yb)                 # mean
                tot_loss += loss.item() * xb.size(0)   # <-- thêm * batch_size
                tot_n    += xb.size(0)
        test_mse = tot_loss / tot_n if tot_n > 0 else float("nan")
        hist_test.append(test_mse)

        print(f"[{tag}] Epoch {ep:03d} | "
              f"train MSE={train_mse:.4e} | test MSE={test_mse:.4e}")

    return model, hist_train, hist_test

# %%
# ================= Cell 9 — Global: Centralized FNN vs FedAvg, and IBR9-only FNN ================= Scenarios A, E.

from pathlib import Path

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---------- Helper: build GLOBAL train dataset (union of all GFLI IBRs) ----------

def build_global_gfli_train_dataset():
    X_list, Y_list = [], []
    for fp, d in loaded_tr:
        if d["family"] == "GFLI":
            X_list.append(d["X"])
            Y_list.append(d["Y"])
    X_raw = np.vstack(X_list)
    Y_raw = np.vstack(Y_list)

    X_scaled = X_scaler_gfli.transform(X_raw)
    Y_scaled = Y_scaler_gfli.transform(Y_raw)

    X_t = torch.from_numpy(X_scaled.astype(np.float32)).to(device)
    Y_t = torch.from_numpy(Y_scaled.astype(np.float32)).to(device)
    ds = TensorDataset(X_t, Y_t)
    print(f"[Global train] #samples={X_t.shape[0]}")
    return ds


def eval_global_mse_on_testsets_macro(model, test_sets, batch_size=512):
    """
    Tính MSE cho từng test-set (từng IBR),
    sau đó lấy trung bình các MSE này (macro-average),
    giống hệt cách FedAvg đang làm.
    """
    model.eval()
    crit = nn.MSELoss()  # mean
    mse_list = []

    with torch.no_grad():
        for ts in test_sets:
            ds = TensorDataset(ts["X"], ts["Y"])
            loader = DataLoader(ds, batch_size=batch_size, shuffle=False)

            total_loss_ts, total_n_ts = 0.0, 0
            for xb, yb in loader:
                xb, yb = xb.to(device), yb.to(device)
                y_pred = model(xb)
                loss = crit(y_pred, yb)            # mean trên batch
                total_loss_ts += loss.item() * xb.size(0)
                total_n_ts    += xb.size(0)

            mse_ts = total_loss_ts / total_n_ts    # MSE riêng cho test-set này
            mse_list.append(mse_ts)

    # macro-average theo IBR (giống FedAvg: np.mean(list_mse))
    return float(np.mean(mse_list)) if mse_list else float("nan")




def train_central_fnn_global(ds_train, test_sets,
                             hidden_dim=HIDDEN_GFLI,
                             epochs=ROUNDS_FL,
                             batch_size=BATCH_SIZE_FL):
    """
    Centralized FNN:
      - Train trên UNION toàn bộ train GFLI (9 IBR)
      - Đánh giá MSE global trên tất cả test-set GFLI
      - Dùng cùng LR schedule với FedAvg (get_lr_for_round_fl).
    """
    trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
    head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
    model = FullModel(trunk, head).to(device)

    loader_tr = DataLoader(ds_train, batch_size=batch_size, shuffle=True)
    crit = nn.MSELoss()  # mean
    opt  = torch.optim.Adam(model.parameters(), lr=LR_INIT_FL)

    hist_tr, hist_te = [], []

    for ep in range(1, epochs + 1):
        # update LR theo schedule giống FedAvg
        lr_ep = get_lr_for_round_fl(ep)
        for g in opt.param_groups:
            g["lr"] = lr_ep

        # ---- TRAIN ----
        model.train()
        total_loss, total_n = 0.0, 0
        for xb, yb in loader_tr:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            y_pred = model(xb)
            loss = crit(y_pred, yb)
            loss.backward()
            opt.step()
            total_loss += loss.item() * xb.size(0)
            total_n    += xb.size(0)
        train_mse = total_loss / total_n

        # ---- TEST (global trên tất cả test-set GFLI) ----
        test_mse = eval_global_mse_on_testsets_macro(model, test_sets, batch_size=batch_size)

        hist_tr.append(train_mse)
        hist_te.append(test_mse)

        print(f"[Central-FNN] Epoch {ep:03d} | train MSE={train_mse:.4e} | test MSE={test_mse:.4e}")

    return model, np.array(hist_tr), np.array(hist_te)


# ================= 1) GLOBAL: Centralized FNN vs FedAvg =================

# Train centralized FNN trên union 9 IBR
ds_train_global = build_global_gfli_train_dataset()
central_model, central_train_curve, central_test_curve = train_central_fnn_global(
    ds_train_global,
    test_sets_gfli,
    hidden_dim=HIDDEN_GFLI,
    epochs=ROUNDS_FL,
    batch_size=BATCH_SIZE_FL,
)


# FedAvg global curves (đã có từ Cell 11)
rounds_axis         = np.array(history_fullfedavg["round"])
fedavg_train_curve  = np.array(history_fullfedavg["train_mse_mean"])
fedavg_test_curve   = np.array(history_fullfedavg["test_mse_mean"])



# ================= 2) IBR9-only: Local FNN (train + test) =================

# Tìm train set cho IBR9 trong clients_gfli
client_ibr9 = None
for c in clients_gfli:
    if c["name"].lower().startswith("gfli9"):
        client_ibr9 = c
        break

if client_ibr9 is None:
    raise RuntimeError("Không tìm thấy client có tên bắt đầu bằng 'gfli9' trong clients_gfli.")

ds_train_ibr9 = client_ibr9["dataset"]
print(f"IBR9 TRAIN: name={client_ibr9['name']}, n={client_ibr9['n']}")

# Tìm test-set cho IBR9 trong test_sets_gfli
ds_test_ibr9 = None
for ts in test_sets_gfli:
    if ts["name"].lower().startswith("gfli9"):
        ds_test_ibr9 = TensorDataset(ts["X"], ts["Y"])
        break

if ds_test_ibr9 is None:
    raise RuntimeError("Không tìm thấy test-set cho IBR9 trong test_sets_gfli.")

def train_fnn_single_ibr(ds_train, ds_test,
                         hidden_dim=HIDDEN_GFLI,
                         epochs=ROUNDS_FL,
                         batch_size=512,
                         lr_init=LR_INIT_FL,
                         tag="FNN-IBR9"):
    """
    Local FNN chỉ train trên IBR9 (train/test curve).
    Dùng cùng LR schedule với FedAvg.
    """
    trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
    head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
    model = FullModel(trunk, head).to(device)

    loader_tr = DataLoader(ds_train, batch_size=batch_size, shuffle=True)
    loader_te = DataLoader(ds_test,  batch_size=batch_size, shuffle=False)

    crit = nn.MSELoss()  # mean
    opt  = torch.optim.Adam(model.parameters(), lr=lr_init)

    hist_tr, hist_te = [], []

    for ep in range(1, epochs + 1):
        lr_ep = get_lr_for_round_fl(ep)
        for g in opt.param_groups:
            g["lr"] = lr_ep

        # ---- TRAIN ----
        model.train()
        total_loss, total_n = 0.0, 0
        for xb, yb in loader_tr:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            y_pred = model(xb)
            loss = crit(y_pred, yb)
            loss.backward()
            opt.step()
            total_loss += loss.item() * xb.size(0)
            total_n += xb.size(0)
        train_mse = total_loss / total_n

        # ---- TEST ----
        model.eval()
        total_loss, total_n = 0.0, 0
        with torch.no_grad():
            for xb, yb in loader_te:
                xb, yb = xb.to(device), yb.to(device)
                y_pred = model(xb)
                loss = crit(y_pred, yb)
                total_loss += loss.item() * xb.size(0)
                total_n += xb.size(0)
        test_mse = total_loss / total_n

        hist_tr.append(train_mse)
        hist_te.append(test_mse)

        print(f"[{tag}] Epoch {ep:03d} | train MSE={train_mse:.4e} | test MSE={test_mse:.4e}")

    return model, np.array(hist_tr), np.array(hist_te)


model_fnn_ibr9, hist_tr_ibr9, hist_te_ibr9 = train_fnn_single_ibr(
    ds_train_ibr9,
    ds_test_ibr9,
    hidden_dim=HIDDEN_GFLI,
    epochs=ROUNDS_FL,
    batch_size=512,
    lr_init=LR_INIT_FL,
    tag="FNN-IBR9",
)


epochs_axis = np.arange(1, ROUNDS_FL + 1)
# Out:
# [Global train] #samples=2060
# [Central-FNN] Epoch 001 | train MSE=1.0300e+00 | test MSE=1.0561e+00
# [Central-FNN] Epoch 002 | train MSE=1.0194e+00 | test MSE=1.0467e+00
# [Central-FNN] Epoch 003 | train MSE=1.0101e+00 | test MSE=1.0377e+00
# [Central-FNN] Epoch 004 | train MSE=1.0011e+00 | test MSE=1.0284e+00
# [Central-FNN] Epoch 005 | train MSE=9.9197e-01 | test MSE=1.0188e+00
# [Central-FNN] Epoch 006 | train MSE=9.8251e-01 | test MSE=1.0085e+00
# [Central-FNN] Epoch 007 | train MSE=9.7220e-01 | test MSE=9.9713e-01
# [Central-FNN] Epoch 008 | train MSE=9.6079e-01 | test MSE=9.8531e-01
# [Central-FNN] Epoch 009 | train MSE=9.4889e-01 | test MSE=9.7273e-01
# [Central-FNN] Epoch 010 | train MSE=9.3552e-01 | test MSE=9.5786e-01
# [Central-FNN] Epoch 011 | train MSE=9.2060e-01 | test MSE=9.4127e-01
# [Central-FNN] Epoch 012 | train MSE=9.0394e-01 | test MSE=9.2359e-01
# [Central-FNN] Epoch 013 | train MSE=8.8663e-01 | test MSE=9.0533e-01
# [Central-FNN] Epoch 014 | train MSE=8.6857e-01 | test MSE=8.8694e-01
# [Central-FNN] Epoch 015 | train MSE=8.5040e-01 | test MSE=8.6871e-01
# [Central-FNN] Epoch 016 | train MSE=8.3198e-01 | test MSE=8.5183e-01
# [Central-FNN] Epoch 017 | train MSE=8.1388e-01 | test MSE=8.3582e-01
# [Central-FNN] Epoch 018 | train MSE=7.9578e-01 | test MSE=8.2065e-01
# [Central-FNN] Epoch 019 | train MSE=7.7873e-01 | test MSE=8.0710e-01
# [Central-FNN] Epoch 020 | train MSE=7.6262e-01 | test MSE=7.9463e-01
# [Central-FNN] Epoch 021 | train MSE=7.4771e-01 | test MSE=7.8282e-01
# [Central-FNN] Epoch 022 | train MSE=7.3402e-01 | test MSE=7.7199e-01
# [Central-FNN] Epoch 023 | train MSE=7.2098e-01 | test MSE=7.6144e-01
# [Central-FNN] Epoch 024 | train MSE=7.0878e-01 | test MSE=7.4977e-01
# [Central-FNN] Epoch 025 | train MSE=6.9719e-01 | test MSE=7.3846e-01
# [Central-FNN] Epoch 026 | train MSE=6.8611e-01 | test MSE=7.2795e-01
# [Central-FNN] Epoch 027 | train MSE=6.7619e-01 | test MSE=7.1702e-01
# [Central-FNN] Epoch 028 | train MSE=6.6642e-01 | test MSE=7.0775e-01
# [Central-FNN] Epoch 029 | train MSE=6.5738e-01 | test MSE=6.9893e-01
# [Central-FNN] Epoch 030 | train MSE=6.4905e-01 | test MSE=6.8899e-01
# [Central-FNN] Epoch 031 | train MSE=6.4015e-01 | test MSE=6.7934e-01
# [Central-FNN] Epoch 032 | train MSE=6.3152e-01 | test MSE=6.6956e-01
# [Central-FNN] Epoch 033 | train MSE=6.2290e-01 | test MSE=6.6038e-01
# [Central-FNN] Epoch 034 | train MSE=6.1440e-01 | test MSE=6.5074e-01
# [Central-FNN] Epoch 035 | train MSE=6.0607e-01 | test MSE=6.4211e-01
# [Central-FNN] Epoch 036 | train MSE=5.9816e-01 | test MSE=6.3326e-01
# [Central-FNN] Epoch 037 | train MSE=5.8993e-01 | test MSE=6.2621e-01
# [Central-FNN] Epoch 038 | train MSE=5.8162e-01 | test MSE=6.1795e-01
# [Central-FNN] Epoch 039 | train MSE=5.7241e-01 | test MSE=6.0849e-01
# [Central-FNN] Epoch 040 | train MSE=5.6236e-01 | test MSE=5.9875e-01
# [Central-FNN] Epoch 041 | train MSE=5.5222e-01 | test MSE=5.8772e-01
# [Central-FNN] Epoch 042 | train MSE=5.4189e-01 | test MSE=5.7707e-01
# [Central-FNN] Epoch 043 | train MSE=5.3155e-01 | test MSE=5.6478e-01
# [Central-FNN] Epoch 044 | train MSE=5.2072e-01 | test MSE=5.5201e-01
# [Central-FNN] Epoch 045 | train MSE=5.1056e-01 | test MSE=5.3965e-01
# [Central-FNN] Epoch 046 | train MSE=5.0109e-01 | test MSE=5.2711e-01
# [Central-FNN] Epoch 047 | train MSE=4.9089e-01 | test MSE=5.1564e-01
# [Central-FNN] Epoch 048 | train MSE=4.7992e-01 | test MSE=5.0538e-01
# [Central-FNN] Epoch 049 | train MSE=4.6892e-01 | test MSE=4.9551e-01
# [Central-FNN] Epoch 050 | train MSE=4.5838e-01 | test MSE=4.8524e-01
# [Central-FNN] Epoch 051 | train MSE=4.4802e-01 | test MSE=4.7556e-01
# [Central-FNN] Epoch 052 | train MSE=4.3783e-01 | test MSE=4.6575e-01
# [Central-FNN] Epoch 053 | train MSE=4.2839e-01 | test MSE=4.5682e-01
# [Central-FNN] Epoch 054 | train MSE=4.1841e-01 | test MSE=4.4666e-01
# [Central-FNN] Epoch 055 | train MSE=4.0907e-01 | test MSE=4.3591e-01
# [Central-FNN] Epoch 056 | train MSE=3.9998e-01 | test MSE=4.2671e-01
# [Central-FNN] Epoch 057 | train MSE=3.9197e-01 | test MSE=4.1673e-01
# [Central-FNN] Epoch 058 | train MSE=3.8368e-01 | test MSE=4.0759e-01
# [Central-FNN] Epoch 059 | train MSE=3.7602e-01 | test MSE=4.0057e-01
# [Central-FNN] Epoch 060 | train MSE=3.6909e-01 | test MSE=3.9659e-01
# [Central-FNN] Epoch 061 | train MSE=3.6270e-01 | test MSE=3.9034e-01
# [Central-FNN] Epoch 062 | train MSE=3.5568e-01 | test MSE=3.8192e-01
# [Central-FNN] Epoch 063 | train MSE=3.5006e-01 | test MSE=3.7259e-01
# [Central-FNN] Epoch 064 | train MSE=3.4568e-01 | test MSE=3.6610e-01
# [Central-FNN] Epoch 065 | train MSE=3.3989e-01 | test MSE=3.6099e-01
# [Central-FNN] Epoch 066 | train MSE=3.3388e-01 | test MSE=3.5858e-01
# [Central-FNN] Epoch 067 | train MSE=3.2869e-01 | test MSE=3.5757e-01
# [Central-FNN] Epoch 068 | train MSE=3.2436e-01 | test MSE=3.5334e-01
# [Central-FNN] Epoch 069 | train MSE=3.1955e-01 | test MSE=3.4685e-01
# [Central-FNN] Epoch 070 | train MSE=3.1488e-01 | test MSE=3.4411e-01
# [Central-FNN] Epoch 071 | train MSE=3.1068e-01 | test MSE=3.3918e-01
# [Central-FNN] Epoch 072 | train MSE=3.0593e-01 | test MSE=3.3056e-01
# [Central-FNN] Epoch 073 | train MSE=3.0117e-01 | test MSE=3.2440e-01
# [Central-FNN] Epoch 074 | train MSE=2.9769e-01 | test MSE=3.1800e-01
# [Central-FNN] Epoch 075 | train MSE=2.9305e-01 | test MSE=3.1580e-01
# [Central-FNN] Epoch 076 | train MSE=2.9003e-01 | test MSE=3.1624e-01
# [Central-FNN] Epoch 077 | train MSE=2.8585e-01 | test MSE=3.1255e-01
# [Central-FNN] Epoch 078 | train MSE=2.8064e-01 | test MSE=3.0736e-01
# [Central-FNN] Epoch 079 | train MSE=2.7580e-01 | test MSE=3.0219e-01
# [Central-FNN] Epoch 080 | train MSE=2.7183e-01 | test MSE=2.9752e-01
# [Central-FNN] Epoch 081 | train MSE=2.6651e-01 | test MSE=2.9386e-01
# [Central-FNN] Epoch 082 | train MSE=2.6147e-01 | test MSE=2.8890e-01
# [Central-FNN] Epoch 083 | train MSE=2.5702e-01 | test MSE=2.8310e-01
# [Central-FNN] Epoch 084 | train MSE=2.5186e-01 | test MSE=2.7455e-01
# [Central-FNN] Epoch 085 | train MSE=2.4790e-01 | test MSE=2.6998e-01
# [Central-FNN] Epoch 086 | train MSE=2.4569e-01 | test MSE=2.6125e-01
# [Central-FNN] Epoch 087 | train MSE=2.3880e-01 | test MSE=2.5640e-01
# [Central-FNN] Epoch 088 | train MSE=2.3443e-01 | test MSE=2.5286e-01
# [Central-FNN] Epoch 089 | train MSE=2.2863e-01 | test MSE=2.5141e-01
# [Central-FNN] Epoch 090 | train MSE=2.2452e-01 | test MSE=2.4795e-01
# [Central-FNN] Epoch 091 | train MSE=2.1913e-01 | test MSE=2.4482e-01
# [Central-FNN] Epoch 092 | train MSE=2.1452e-01 | test MSE=2.3774e-01
# [Central-FNN] Epoch 093 | train MSE=2.0887e-01 | test MSE=2.3113e-01
# [Central-FNN] Epoch 094 | train MSE=2.0438e-01 | test MSE=2.2692e-01
# [Central-FNN] Epoch 095 | train MSE=2.0046e-01 | test MSE=2.2488e-01
# [Central-FNN] Epoch 096 | train MSE=1.9556e-01 | test MSE=2.2532e-01
# [Central-FNN] Epoch 097 | train MSE=1.9205e-01 | test MSE=2.2089e-01
# [Central-FNN] Epoch 098 | train MSE=1.8709e-01 | test MSE=2.1195e-01
# [Central-FNN] Epoch 099 | train MSE=1.8168e-01 | test MSE=2.0320e-01
# [Central-FNN] Epoch 100 | train MSE=1.7660e-01 | test MSE=1.9548e-01
# [Central-FNN] Epoch 101 | train MSE=1.7167e-01 | test MSE=1.9035e-01
# [Central-FNN] Epoch 102 | train MSE=1.6760e-01 | test MSE=1.8788e-01
# [Central-FNN] Epoch 103 | train MSE=1.6325e-01 | test MSE=1.8310e-01
# [Central-FNN] Epoch 104 | train MSE=1.5883e-01 | test MSE=1.7760e-01
# [Central-FNN] Epoch 105 | train MSE=1.5435e-01 | test MSE=1.7403e-01
# [Central-FNN] Epoch 106 | train MSE=1.5025e-01 | test MSE=1.6948e-01
# [Central-FNN] Epoch 107 | train MSE=1.4598e-01 | test MSE=1.6632e-01
# [Central-FNN] Epoch 108 | train MSE=1.4197e-01 | test MSE=1.6372e-01
# [Central-FNN] Epoch 109 | train MSE=1.3832e-01 | test MSE=1.6055e-01
# [Central-FNN] Epoch 110 | train MSE=1.3399e-01 | test MSE=1.5204e-01
# [Central-FNN] Epoch 111 | train MSE=1.3021e-01 | test MSE=1.4778e-01
# [Central-FNN] Epoch 112 | train MSE=1.2673e-01 | test MSE=1.4534e-01
# [Central-FNN] Epoch 113 | train MSE=1.2307e-01 | test MSE=1.4127e-01
# [Central-FNN] Epoch 114 | train MSE=1.1970e-01 | test MSE=1.3741e-01
# [Central-FNN] Epoch 115 | train MSE=1.1673e-01 | test MSE=1.3434e-01
# [Central-FNN] Epoch 116 | train MSE=1.1372e-01 | test MSE=1.3219e-01
# [Central-FNN] Epoch 117 | train MSE=1.1058e-01 | test MSE=1.3035e-01
# [Central-FNN] Epoch 118 | train MSE=1.0789e-01 | test MSE=1.2657e-01
# [Central-FNN] Epoch 119 | train MSE=1.0513e-01 | test MSE=1.2264e-01
# [Central-FNN] Epoch 120 | train MSE=1.0299e-01 | test MSE=1.2015e-01
# [Central-FNN] Epoch 121 | train MSE=1.0039e-01 | test MSE=1.1921e-01
# [Central-FNN] Epoch 122 | train MSE=9.7856e-02 | test MSE=1.1856e-01
# [Central-FNN] Epoch 123 | train MSE=9.5691e-02 | test MSE=1.1484e-01
# [Central-FNN] Epoch 124 | train MSE=9.3251e-02 | test MSE=1.1008e-01
# [Central-FNN] Epoch 125 | train MSE=9.2582e-02 | test MSE=1.0821e-01
# [Central-FNN] Epoch 126 | train MSE=9.0185e-02 | test MSE=1.0826e-01
# [Central-FNN] Epoch 127 | train MSE=8.8119e-02 | test MSE=1.0812e-01
# [Central-FNN] Epoch 128 | train MSE=8.5793e-02 | test MSE=1.0480e-01
# [Central-FNN] Epoch 129 | train MSE=8.3871e-02 | test MSE=1.0079e-01
# [Central-FNN] Epoch 130 | train MSE=8.1949e-02 | test MSE=9.8621e-02
# [Central-FNN] Epoch 131 | train MSE=8.0205e-02 | test MSE=9.6169e-02
# [Central-FNN] Epoch 132 | train MSE=7.8827e-02 | test MSE=9.5279e-02
# [Central-FNN] Epoch 133 | train MSE=7.7285e-02 | test MSE=9.3986e-02
# [Central-FNN] Epoch 134 | train MSE=7.6092e-02 | test MSE=9.1485e-02
# [Central-FNN] Epoch 135 | train MSE=7.5265e-02 | test MSE=9.0254e-02
# [Central-FNN] Epoch 136 | train MSE=7.3458e-02 | test MSE=8.8832e-02
# [Central-FNN] Epoch 137 | train MSE=7.1848e-02 | test MSE=8.9599e-02
# [Central-FNN] Epoch 138 | train MSE=7.0689e-02 | test MSE=9.1138e-02
# [Central-FNN] Epoch 139 | train MSE=7.0333e-02 | test MSE=9.0836e-02
# [Central-FNN] Epoch 140 | train MSE=6.9129e-02 | test MSE=8.8000e-02
# [Central-FNN] Epoch 141 | train MSE=6.7695e-02 | test MSE=8.4762e-02
# [Central-FNN] Epoch 142 | train MSE=6.6544e-02 | test MSE=8.2890e-02
# [Central-FNN] Epoch 143 | train MSE=6.5589e-02 | test MSE=8.2156e-02
# [Central-FNN] Epoch 144 | train MSE=6.4470e-02 | test MSE=8.0911e-02
# [Central-FNN] Epoch 145 | train MSE=6.3443e-02 | test MSE=8.0622e-02
# [Central-FNN] Epoch 146 | train MSE=6.3487e-02 | test MSE=7.8872e-02
# [Central-FNN] Epoch 147 | train MSE=6.2059e-02 | test MSE=7.7244e-02
# [Central-FNN] Epoch 148 | train MSE=6.1197e-02 | test MSE=7.5474e-02
# [Central-FNN] Epoch 149 | train MSE=5.9701e-02 | test MSE=7.5952e-02
# [Central-FNN] Epoch 150 | train MSE=5.9196e-02 | test MSE=7.6203e-02
# [Central-FNN] Epoch 151 | train MSE=5.8546e-02 | test MSE=7.5173e-02
# [Central-FNN] Epoch 152 | train MSE=5.7479e-02 | test MSE=7.4879e-02
# [Central-FNN] Epoch 153 | train MSE=5.6918e-02 | test MSE=7.4718e-02
# [Central-FNN] Epoch 154 | train MSE=5.6186e-02 | test MSE=7.1501e-02
# [Central-FNN] Epoch 155 | train MSE=5.4969e-02 | test MSE=7.0028e-02
# [Central-FNN] Epoch 156 | train MSE=5.4055e-02 | test MSE=6.9565e-02
# [Central-FNN] Epoch 157 | train MSE=5.3501e-02 | test MSE=6.8298e-02
# [Central-FNN] Epoch 158 | train MSE=5.2612e-02 | test MSE=6.6835e-02
# [Central-FNN] Epoch 159 | train MSE=5.1903e-02 | test MSE=6.5947e-02
# [Central-FNN] Epoch 160 | train MSE=5.1233e-02 | test MSE=6.5665e-02
# [Central-FNN] Epoch 161 | train MSE=5.0700e-02 | test MSE=6.5798e-02
# [Central-FNN] Epoch 162 | train MSE=4.9871e-02 | test MSE=6.5071e-02
# [Central-FNN] Epoch 163 | train MSE=4.9229e-02 | test MSE=6.3902e-02
# [Central-FNN] Epoch 164 | train MSE=4.8459e-02 | test MSE=6.3564e-02
# [Central-FNN] Epoch 165 | train MSE=4.7792e-02 | test MSE=6.3109e-02
# [Central-FNN] Epoch 166 | train MSE=4.7315e-02 | test MSE=6.3036e-02
# [Central-FNN] Epoch 167 | train MSE=4.6788e-02 | test MSE=6.2368e-02
# [Central-FNN] Epoch 168 | train MSE=4.6178e-02 | test MSE=6.1015e-02
# [Central-FNN] Epoch 169 | train MSE=4.5397e-02 | test MSE=5.8359e-02
# [Central-FNN] Epoch 170 | train MSE=4.4860e-02 | test MSE=5.7895e-02
# [Central-FNN] Epoch 171 | train MSE=4.4213e-02 | test MSE=5.8393e-02
# [Central-FNN] Epoch 172 | train MSE=4.3908e-02 | test MSE=5.8299e-02
# [Central-FNN] Epoch 173 | train MSE=4.3290e-02 | test MSE=5.5527e-02
# [Central-FNN] Epoch 174 | train MSE=4.3213e-02 | test MSE=5.4251e-02
# [Central-FNN] Epoch 175 | train MSE=4.2966e-02 | test MSE=5.4026e-02
# [Central-FNN] Epoch 176 | train MSE=4.1970e-02 | test MSE=5.5160e-02
# [Central-FNN] Epoch 177 | train MSE=4.1672e-02 | test MSE=5.5610e-02
# [Central-FNN] Epoch 178 | train MSE=4.0916e-02 | test MSE=5.4235e-02
# [Central-FNN] Epoch 179 | train MSE=4.0261e-02 | test MSE=5.2768e-02
# [Central-FNN] Epoch 180 | train MSE=3.9773e-02 | test MSE=5.2119e-02
# [Central-FNN] Epoch 181 | train MSE=3.9180e-02 | test MSE=5.1998e-02
# [Central-FNN] Epoch 182 | train MSE=3.8583e-02 | test MSE=5.1259e-02
# [Central-FNN] Epoch 183 | train MSE=3.8454e-02 | test MSE=4.9722e-02
# [Central-FNN] Epoch 184 | train MSE=3.7859e-02 | test MSE=4.9582e-02
# [Central-FNN] Epoch 185 | train MSE=3.7473e-02 | test MSE=4.9562e-02
# [Central-FNN] Epoch 186 | train MSE=3.6938e-02 | test MSE=4.9615e-02
# [Central-FNN] Epoch 187 | train MSE=3.6637e-02 | test MSE=4.9697e-02
# [Central-FNN] Epoch 188 | train MSE=3.6043e-02 | test MSE=4.9160e-02
# [Central-FNN] Epoch 189 | train MSE=3.5752e-02 | test MSE=4.9214e-02
# [Central-FNN] Epoch 190 | train MSE=3.5256e-02 | test MSE=4.7885e-02
# [Central-FNN] Epoch 191 | train MSE=3.4766e-02 | test MSE=4.6378e-02
# [Central-FNN] Epoch 192 | train MSE=3.4368e-02 | test MSE=4.4414e-02
# [Central-FNN] Epoch 193 | train MSE=3.4315e-02 | test MSE=4.4219e-02
# [Central-FNN] Epoch 194 | train MSE=3.3622e-02 | test MSE=4.4315e-02
# [Central-FNN] Epoch 195 | train MSE=3.3164e-02 | test MSE=4.4356e-02
# [Central-FNN] Epoch 196 | train MSE=3.2622e-02 | test MSE=4.4086e-02
# [Central-FNN] Epoch 197 | train MSE=3.2351e-02 | test MSE=4.3366e-02
# [Central-FNN] Epoch 198 | train MSE=3.1867e-02 | test MSE=4.2848e-02
# [Central-FNN] Epoch 199 | train MSE=3.1588e-02 | test MSE=4.2577e-02
# [Central-FNN] Epoch 200 | train MSE=3.1233e-02 | test MSE=4.1973e-02
# IBR9 TRAIN: name=gfli9_impedance_dataset, n=40
# [FNN-IBR9] Epoch 001 | train MSE=7.9668e-01 | test MSE=8.4774e-01
# [FNN-IBR9] Epoch 002 | train MSE=7.9148e-01 | test MSE=8.4271e-01
# [FNN-IBR9] Epoch 003 | train MSE=7.8646e-01 | test MSE=8.3785e-01
# [FNN-IBR9] Epoch 004 | train MSE=7.8165e-01 | test MSE=8.3322e-01
# [FNN-IBR9] Epoch 005 | train MSE=7.7705e-01 | test MSE=8.2870e-01
# [FNN-IBR9] Epoch 006 | train MSE=7.7260e-01 | test MSE=8.2427e-01
# [FNN-IBR9] Epoch 007 | train MSE=7.6830e-01 | test MSE=8.2007e-01
# [FNN-IBR9] Epoch 008 | train MSE=7.6420e-01 | test MSE=8.1612e-01
# [FNN-IBR9] Epoch 009 | train MSE=7.6036e-01 | test MSE=8.1234e-01
# [FNN-IBR9] Epoch 010 | train MSE=7.5667e-01 | test MSE=8.0876e-01
# [FNN-IBR9] Epoch 011 | train MSE=7.5319e-01 | test MSE=8.0538e-01
# [FNN-IBR9] Epoch 012 | train MSE=7.4981e-01 | test MSE=8.0213e-01
# [FNN-IBR9] Epoch 013 | train MSE=7.4654e-01 | test MSE=7.9898e-01
# [FNN-IBR9] Epoch 014 | train MSE=7.4334e-01 | test MSE=7.9597e-01
# [FNN-IBR9] Epoch 015 | train MSE=7.4027e-01 | test MSE=7.9308e-01
# [FNN-IBR9] Epoch 016 | train MSE=7.3729e-01 | test MSE=7.9033e-01
# [FNN-IBR9] Epoch 017 | train MSE=7.3442e-01 | test MSE=7.8767e-01
# [FNN-IBR9] Epoch 018 | train MSE=7.3159e-01 | test MSE=7.8508e-01
# [FNN-IBR9] Epoch 019 | train MSE=7.2882e-01 | test MSE=7.8256e-01
# [FNN-IBR9] Epoch 020 | train MSE=7.2609e-01 | test MSE=7.8012e-01
# [FNN-IBR9] Epoch 021 | train MSE=7.2339e-01 | test MSE=7.7772e-01
# [FNN-IBR9] Epoch 022 | train MSE=7.2072e-01 | test MSE=7.7537e-01
# [FNN-IBR9] Epoch 023 | train MSE=7.1807e-01 | test MSE=7.7307e-01
# [FNN-IBR9] Epoch 024 | train MSE=7.1544e-01 | test MSE=7.7080e-01
# [FNN-IBR9] Epoch 025 | train MSE=7.1280e-01 | test MSE=7.6852e-01
# [FNN-IBR9] Epoch 026 | train MSE=7.1011e-01 | test MSE=7.6627e-01
# [FNN-IBR9] Epoch 027 | train MSE=7.0736e-01 | test MSE=7.6405e-01
# [FNN-IBR9] Epoch 028 | train MSE=7.0457e-01 | test MSE=7.6186e-01
# [FNN-IBR9] Epoch 029 | train MSE=7.0173e-01 | test MSE=7.5967e-01
# [FNN-IBR9] Epoch 030 | train MSE=6.9881e-01 | test MSE=7.5749e-01
# [FNN-IBR9] Epoch 031 | train MSE=6.9582e-01 | test MSE=7.5532e-01
# [FNN-IBR9] Epoch 032 | train MSE=6.9280e-01 | test MSE=7.5315e-01
# [FNN-IBR9] Epoch 033 | train MSE=6.8973e-01 | test MSE=7.5104e-01
# [FNN-IBR9] Epoch 034 | train MSE=6.8659e-01 | test MSE=7.4897e-01
# [FNN-IBR9] Epoch 035 | train MSE=6.8339e-01 | test MSE=7.4687e-01
# [FNN-IBR9] Epoch 036 | train MSE=6.8011e-01 | test MSE=7.4476e-01
# [FNN-IBR9] Epoch 037 | train MSE=6.7673e-01 | test MSE=7.4260e-01
# [FNN-IBR9] Epoch 038 | train MSE=6.7320e-01 | test MSE=7.4047e-01
# [FNN-IBR9] Epoch 039 | train MSE=6.6955e-01 | test MSE=7.3841e-01
# [FNN-IBR9] Epoch 040 | train MSE=6.6587e-01 | test MSE=7.3639e-01
# [FNN-IBR9] Epoch 041 | train MSE=6.6212e-01 | test MSE=7.3437e-01
# [FNN-IBR9] Epoch 042 | train MSE=6.5832e-01 | test MSE=7.3242e-01
# [FNN-IBR9] Epoch 043 | train MSE=6.5447e-01 | test MSE=7.3053e-01
# [FNN-IBR9] Epoch 044 | train MSE=6.5054e-01 | test MSE=7.2875e-01
# [FNN-IBR9] Epoch 045 | train MSE=6.4654e-01 | test MSE=7.2703e-01
# [FNN-IBR9] Epoch 046 | train MSE=6.4247e-01 | test MSE=7.2533e-01
# [FNN-IBR9] Epoch 047 | train MSE=6.3837e-01 | test MSE=7.2373e-01
# [FNN-IBR9] Epoch 048 | train MSE=6.3421e-01 | test MSE=7.2225e-01
# [FNN-IBR9] Epoch 049 | train MSE=6.3000e-01 | test MSE=7.2089e-01
# [FNN-IBR9] Epoch 050 | train MSE=6.2574e-01 | test MSE=7.1969e-01
# [FNN-IBR9] Epoch 051 | train MSE=6.2146e-01 | test MSE=7.1864e-01
# [FNN-IBR9] Epoch 052 | train MSE=6.1714e-01 | test MSE=7.1773e-01
# [FNN-IBR9] Epoch 053 | train MSE=6.1280e-01 | test MSE=7.1697e-01
# [FNN-IBR9] Epoch 054 | train MSE=6.0843e-01 | test MSE=7.1635e-01
# [FNN-IBR9] Epoch 055 | train MSE=6.0403e-01 | test MSE=7.1592e-01
# [FNN-IBR9] Epoch 056 | train MSE=5.9964e-01 | test MSE=7.1568e-01
# [FNN-IBR9] Epoch 057 | train MSE=5.9523e-01 | test MSE=7.1560e-01
# [FNN-IBR9] Epoch 058 | train MSE=5.9078e-01 | test MSE=7.1568e-01
# [FNN-IBR9] Epoch 059 | train MSE=5.8631e-01 | test MSE=7.1594e-01
# [FNN-IBR9] Epoch 060 | train MSE=5.8182e-01 | test MSE=7.1637e-01
# [FNN-IBR9] Epoch 061 | train MSE=5.7729e-01 | test MSE=7.1698e-01
# [FNN-IBR9] Epoch 062 | train MSE=5.7274e-01 | test MSE=7.1776e-01
# [FNN-IBR9] Epoch 063 | train MSE=5.6815e-01 | test MSE=7.1872e-01
# [FNN-IBR9] Epoch 064 | train MSE=5.6356e-01 | test MSE=7.1987e-01
# [FNN-IBR9] Epoch 065 | train MSE=5.5896e-01 | test MSE=7.2122e-01
# [FNN-IBR9] Epoch 066 | train MSE=5.5438e-01 | test MSE=7.2279e-01
# [FNN-IBR9] Epoch 067 | train MSE=5.4987e-01 | test MSE=7.2460e-01
# [FNN-IBR9] Epoch 068 | train MSE=5.4539e-01 | test MSE=7.2664e-01
# [FNN-IBR9] Epoch 069 | train MSE=5.4092e-01 | test MSE=7.2889e-01
# [FNN-IBR9] Epoch 070 | train MSE=5.3642e-01 | test MSE=7.3135e-01
# [FNN-IBR9] Epoch 071 | train MSE=5.3189e-01 | test MSE=7.3398e-01
# [FNN-IBR9] Epoch 072 | train MSE=5.2734e-01 | test MSE=7.3683e-01
# [FNN-IBR9] Epoch 073 | train MSE=5.2281e-01 | test MSE=7.3994e-01
# [FNN-IBR9] Epoch 074 | train MSE=5.1833e-01 | test MSE=7.4327e-01
# [FNN-IBR9] Epoch 075 | train MSE=5.1385e-01 | test MSE=7.4679e-01
# [FNN-IBR9] Epoch 076 | train MSE=5.0935e-01 | test MSE=7.5050e-01
# [FNN-IBR9] Epoch 077 | train MSE=5.0482e-01 | test MSE=7.5438e-01
# [FNN-IBR9] Epoch 078 | train MSE=5.0029e-01 | test MSE=7.5838e-01
# [FNN-IBR9] Epoch 079 | train MSE=4.9577e-01 | test MSE=7.6249e-01
# [FNN-IBR9] Epoch 080 | train MSE=4.9131e-01 | test MSE=7.6678e-01
# [FNN-IBR9] Epoch 081 | train MSE=4.8693e-01 | test MSE=7.7119e-01
# [FNN-IBR9] Epoch 082 | train MSE=4.8257e-01 | test MSE=7.7577e-01
# [FNN-IBR9] Epoch 083 | train MSE=4.7825e-01 | test MSE=7.8048e-01
# [FNN-IBR9] Epoch 084 | train MSE=4.7397e-01 | test MSE=7.8532e-01
# [FNN-IBR9] Epoch 085 | train MSE=4.6975e-01 | test MSE=7.9027e-01
# [FNN-IBR9] Epoch 086 | train MSE=4.6562e-01 | test MSE=7.9522e-01
# [FNN-IBR9] Epoch 087 | train MSE=4.6152e-01 | test MSE=8.0025e-01
# [FNN-IBR9] Epoch 088 | train MSE=4.5748e-01 | test MSE=8.0542e-01
# [FNN-IBR9] Epoch 089 | train MSE=4.5355e-01 | test MSE=8.1075e-01
# [FNN-IBR9] Epoch 090 | train MSE=4.4966e-01 | test MSE=8.1626e-01
# [FNN-IBR9] Epoch 091 | train MSE=4.4589e-01 | test MSE=8.2194e-01
# [FNN-IBR9] Epoch 092 | train MSE=4.4223e-01 | test MSE=8.2759e-01
# [FNN-IBR9] Epoch 093 | train MSE=4.3867e-01 | test MSE=8.3329e-01
# [FNN-IBR9] Epoch 094 | train MSE=4.3522e-01 | test MSE=8.3921e-01
# [FNN-IBR9] Epoch 095 | train MSE=4.3192e-01 | test MSE=8.4533e-01
# [FNN-IBR9] Epoch 096 | train MSE=4.2868e-01 | test MSE=8.5146e-01
# [FNN-IBR9] Epoch 097 | train MSE=4.2552e-01 | test MSE=8.5767e-01
# [FNN-IBR9] Epoch 098 | train MSE=4.2249e-01 | test MSE=8.6397e-01
# [FNN-IBR9] Epoch 099 | train MSE=4.1953e-01 | test MSE=8.7050e-01
# [FNN-IBR9] Epoch 100 | train MSE=4.1667e-01 | test MSE=8.7712e-01
# [FNN-IBR9] Epoch 101 | train MSE=4.1390e-01 | test MSE=8.8359e-01
# [FNN-IBR9] Epoch 102 | train MSE=4.1129e-01 | test MSE=8.9000e-01
# [FNN-IBR9] Epoch 103 | train MSE=4.0876e-01 | test MSE=8.9635e-01
# [FNN-IBR9] Epoch 104 | train MSE=4.0631e-01 | test MSE=9.0262e-01
# [FNN-IBR9] Epoch 105 | train MSE=4.0392e-01 | test MSE=9.0885e-01
# [FNN-IBR9] Epoch 106 | train MSE=4.0161e-01 | test MSE=9.1494e-01
# [FNN-IBR9] Epoch 107 | train MSE=3.9938e-01 | test MSE=9.2077e-01
# [FNN-IBR9] Epoch 108 | train MSE=3.9721e-01 | test MSE=9.2628e-01
# [FNN-IBR9] Epoch 109 | train MSE=3.9511e-01 | test MSE=9.3148e-01
# [FNN-IBR9] Epoch 110 | train MSE=3.9306e-01 | test MSE=9.3658e-01
# [FNN-IBR9] Epoch 111 | train MSE=3.9110e-01 | test MSE=9.4166e-01
# [FNN-IBR9] Epoch 112 | train MSE=3.8921e-01 | test MSE=9.4661e-01
# [FNN-IBR9] Epoch 113 | train MSE=3.8739e-01 | test MSE=9.5136e-01
# [FNN-IBR9] Epoch 114 | train MSE=3.8568e-01 | test MSE=9.5621e-01
# [FNN-IBR9] Epoch 115 | train MSE=3.8407e-01 | test MSE=9.6088e-01
# [FNN-IBR9] Epoch 116 | train MSE=3.8252e-01 | test MSE=9.6537e-01
# [FNN-IBR9] Epoch 117 | train MSE=3.8103e-01 | test MSE=9.6974e-01
# [FNN-IBR9] Epoch 118 | train MSE=3.7957e-01 | test MSE=9.7397e-01
# [FNN-IBR9] Epoch 119 | train MSE=3.7815e-01 | test MSE=9.7810e-01
# [FNN-IBR9] Epoch 120 | train MSE=3.7678e-01 | test MSE=9.8203e-01
# [FNN-IBR9] Epoch 121 | train MSE=3.7544e-01 | test MSE=9.8548e-01
# [FNN-IBR9] Epoch 122 | train MSE=3.7413e-01 | test MSE=9.8854e-01
# [FNN-IBR9] Epoch 123 | train MSE=3.7286e-01 | test MSE=9.9115e-01
# [FNN-IBR9] Epoch 124 | train MSE=3.7163e-01 | test MSE=9.9337e-01
# [FNN-IBR9] Epoch 125 | train MSE=3.7042e-01 | test MSE=9.9547e-01
# [FNN-IBR9] Epoch 126 | train MSE=3.6926e-01 | test MSE=9.9723e-01
# [FNN-IBR9] Epoch 127 | train MSE=3.6813e-01 | test MSE=9.9879e-01
# [FNN-IBR9] Epoch 128 | train MSE=3.6701e-01 | test MSE=1.0000e+00
# [FNN-IBR9] Epoch 129 | train MSE=3.6591e-01 | test MSE=1.0012e+00
# [FNN-IBR9] Epoch 130 | train MSE=3.6482e-01 | test MSE=1.0020e+00
# [FNN-IBR9] Epoch 131 | train MSE=3.6374e-01 | test MSE=1.0025e+00
# [FNN-IBR9] Epoch 132 | train MSE=3.6266e-01 | test MSE=1.0025e+00
# [FNN-IBR9] Epoch 133 | train MSE=3.6157e-01 | test MSE=1.0023e+00
# [FNN-IBR9] Epoch 134 | train MSE=3.6052e-01 | test MSE=1.0023e+00
# [FNN-IBR9] Epoch 135 | train MSE=3.5947e-01 | test MSE=1.0025e+00
# [FNN-IBR9] Epoch 136 | train MSE=3.5840e-01 | test MSE=1.0028e+00
# [FNN-IBR9] Epoch 137 | train MSE=3.5732e-01 | test MSE=1.0033e+00
# [FNN-IBR9] Epoch 138 | train MSE=3.5629e-01 | test MSE=1.0034e+00
# [FNN-IBR9] Epoch 139 | train MSE=3.5523e-01 | test MSE=1.0030e+00
# [FNN-IBR9] Epoch 140 | train MSE=3.5412e-01 | test MSE=1.0027e+00
# [FNN-IBR9] Epoch 141 | train MSE=3.5302e-01 | test MSE=1.0024e+00
# [FNN-IBR9] Epoch 142 | train MSE=3.5191e-01 | test MSE=1.0020e+00
# [FNN-IBR9] Epoch 143 | train MSE=3.5078e-01 | test MSE=1.0017e+00
# [FNN-IBR9] Epoch 144 | train MSE=3.4966e-01 | test MSE=1.0014e+00
# [FNN-IBR9] Epoch 145 | train MSE=3.4850e-01 | test MSE=1.0012e+00
# [FNN-IBR9] Epoch 146 | train MSE=3.4732e-01 | test MSE=1.0011e+00
# [FNN-IBR9] Epoch 147 | train MSE=3.4613e-01 | test MSE=1.0011e+00
# [FNN-IBR9] Epoch 148 | train MSE=3.4490e-01 | test MSE=1.0011e+00
# [FNN-IBR9] Epoch 149 | train MSE=3.4366e-01 | test MSE=1.0010e+00
# [FNN-IBR9] Epoch 150 | train MSE=3.4239e-01 | test MSE=1.0008e+00
# [FNN-IBR9] Epoch 151 | train MSE=3.4110e-01 | test MSE=1.0005e+00
# [FNN-IBR9] Epoch 152 | train MSE=3.3980e-01 | test MSE=9.9994e-01
# [FNN-IBR9] Epoch 153 | train MSE=3.3844e-01 | test MSE=9.9956e-01
# [FNN-IBR9] Epoch 154 | train MSE=3.3707e-01 | test MSE=9.9943e-01
# [FNN-IBR9] Epoch 155 | train MSE=3.3565e-01 | test MSE=9.9952e-01
# [FNN-IBR9] Epoch 156 | train MSE=3.3422e-01 | test MSE=9.9911e-01
# [FNN-IBR9] Epoch 157 | train MSE=3.3278e-01 | test MSE=9.9795e-01
# [FNN-IBR9] Epoch 158 | train MSE=3.3127e-01 | test MSE=9.9677e-01
# [FNN-IBR9] Epoch 159 | train MSE=3.2977e-01 | test MSE=9.9560e-01
# [FNN-IBR9] Epoch 160 | train MSE=3.2820e-01 | test MSE=9.9447e-01
# [FNN-IBR9] Epoch 161 | train MSE=3.2660e-01 | test MSE=9.9306e-01
# [FNN-IBR9] Epoch 162 | train MSE=3.2495e-01 | test MSE=9.9176e-01
# [FNN-IBR9] Epoch 163 | train MSE=3.2328e-01 | test MSE=9.9056e-01
# [FNN-IBR9] Epoch 164 | train MSE=3.2158e-01 | test MSE=9.8926e-01
# [FNN-IBR9] Epoch 165 | train MSE=3.1986e-01 | test MSE=9.8785e-01
# [FNN-IBR9] Epoch 166 | train MSE=3.1807e-01 | test MSE=9.8617e-01
# [FNN-IBR9] Epoch 167 | train MSE=3.1628e-01 | test MSE=9.8484e-01
# [FNN-IBR9] Epoch 168 | train MSE=3.1443e-01 | test MSE=9.8372e-01
# [FNN-IBR9] Epoch 169 | train MSE=3.1256e-01 | test MSE=9.8233e-01
# [FNN-IBR9] Epoch 170 | train MSE=3.1065e-01 | test MSE=9.8088e-01
# [FNN-IBR9] Epoch 171 | train MSE=3.0869e-01 | test MSE=9.7975e-01
# [FNN-IBR9] Epoch 172 | train MSE=3.0668e-01 | test MSE=9.7865e-01
# [FNN-IBR9] Epoch 173 | train MSE=3.0464e-01 | test MSE=9.7766e-01
# [FNN-IBR9] Epoch 174 | train MSE=3.0254e-01 | test MSE=9.7684e-01
# [FNN-IBR9] Epoch 175 | train MSE=3.0039e-01 | test MSE=9.7656e-01
# [FNN-IBR9] Epoch 176 | train MSE=2.9822e-01 | test MSE=9.7577e-01
# [FNN-IBR9] Epoch 177 | train MSE=2.9597e-01 | test MSE=9.7427e-01
# [FNN-IBR9] Epoch 178 | train MSE=2.9369e-01 | test MSE=9.7281e-01
# [FNN-IBR9] Epoch 179 | train MSE=2.9137e-01 | test MSE=9.7178e-01
# [FNN-IBR9] Epoch 180 | train MSE=2.8899e-01 | test MSE=9.7120e-01
# [FNN-IBR9] Epoch 181 | train MSE=2.8654e-01 | test MSE=9.7070e-01
# [FNN-IBR9] Epoch 182 | train MSE=2.8405e-01 | test MSE=9.6991e-01
# [FNN-IBR9] Epoch 183 | train MSE=2.8151e-01 | test MSE=9.6873e-01
# [FNN-IBR9] Epoch 184 | train MSE=2.7893e-01 | test MSE=9.6692e-01
# [FNN-IBR9] Epoch 185 | train MSE=2.7635e-01 | test MSE=9.6560e-01
# [FNN-IBR9] Epoch 186 | train MSE=2.7372e-01 | test MSE=9.6475e-01
# [FNN-IBR9] Epoch 187 | train MSE=2.7101e-01 | test MSE=9.6386e-01
# [FNN-IBR9] Epoch 188 | train MSE=2.6824e-01 | test MSE=9.6295e-01
# [FNN-IBR9] Epoch 189 | train MSE=2.6542e-01 | test MSE=9.6234e-01
# [FNN-IBR9] Epoch 190 | train MSE=2.6261e-01 | test MSE=9.6116e-01
# [FNN-IBR9] Epoch 191 | train MSE=2.5969e-01 | test MSE=9.6017e-01
# [FNN-IBR9] Epoch 192 | train MSE=2.5676e-01 | test MSE=9.5917e-01
# [FNN-IBR9] Epoch 193 | train MSE=2.5375e-01 | test MSE=9.5831e-01
# [FNN-IBR9] Epoch 194 | train MSE=2.5072e-01 | test MSE=9.5764e-01
# [FNN-IBR9] Epoch 195 | train MSE=2.4763e-01 | test MSE=9.5717e-01
# [FNN-IBR9] Epoch 196 | train MSE=2.4448e-01 | test MSE=9.5637e-01
# [FNN-IBR9] Epoch 197 | train MSE=2.4129e-01 | test MSE=9.5583e-01
# [FNN-IBR9] Epoch 198 | train MSE=2.3807e-01 | test MSE=9.5522e-01
# [FNN-IBR9] Epoch 199 | train MSE=2.3477e-01 | test MSE=9.5483e-01
# [FNN-IBR9] Epoch 200 | train MSE=2.3147e-01 | test MSE=9.5369e-01

# %%
# %run -i plot_fl_central_local_combined.py
# Out:
# Training/evaluating local-only models and collecting metrics...
#   IBR1: Local=3.4154e-01 | FedAvg=4.5753e-02 | Central=3.6964e-02
#   IBR2: Local=2.9758e-01 | FedAvg=6.4449e-02 | Central=4.5328e-02
#   IBR3: Local=4.7852e-01 | FedAvg=5.5260e-02 | Central=4.5755e-02
#   IBR4: Local=2.0177e-01 | FedAvg=7.4890e-02 | Central=4.8794e-02
#   IBR5: Local=3.5681e-01 | FedAvg=3.3528e-02 | Central=2.5019e-02
#   IBR6: Local=5.3387e-01 | FedAvg=5.4033e-02 | Central=3.6809e-02
#   IBR7: Local=4.6684e-01 | FedAvg=4.4167e-02 | Central=3.3533e-02
#   IBR8: Local=2.3565e-01 | FedAvg=7.7154e-02 | Central=5.6476e-02
#   IBR9: Local=6.7024e-01 | FedAvg=7.1984e-02 | Central=4.9075e-02
# C:\Users\ACER\OneDrive - Umich\My PhD\Research\Topic discussion\Impedance-based Stability Analysis\ML_basedIMEst\FL\CodeImplement\plot_fl_central_local_combined.py:447: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.set_ylabel("Test MSE")
# C:\Users\ACER\OneDrive - Umich\My PhD\Research\Topic discussion\Impedance-based Stability Analysis\ML_basedIMEst\FL\CodeImplement\plot_fl_central_local_combined.py:511: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   # (a) Final MSE
# C:\Users\ACER\OneDrive - Umich\My PhD\Research\Topic discussion\Impedance-based Stability Analysis\ML_basedIMEst\FL\CodeImplement\plot_fl_central_local_combined.py:512: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   axes[0].bar(labels, final_mse, color=[COLOR_FED, COLOR_CENT, COLOR_LOCAL], alpha=0.9, edgecolor="black", linewidth=0.5)
# C:\Users\ACER\OneDrive - Umich\My PhD\Research\Topic discussion\Impedance-based Stability Analysis\ML_basedIMEst\FL\CodeImplement\plot_fl_central_local_combined.py:513: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   axes[0].set_ylabel("Final Test MSE")
# [BODE] Saved TRUE vs predicted curves for gfli1_test_impedance_dataset_copy.
# Done. Figures saved:
# - fig_combined_per_ibr_bar.pdf/svg
# - fig_combined_boxplot_mse.pdf/svg
# - fig_combined_final_metrics.pdf/svg
# - fig_combined_fairness_scatter.pdf/svg
# - fig_combined_cdf_error.pdf/svg
# - fig_combined_bode_re_*.pdf/svg and fig_combined_bode_im_*.pdf/svg

# %%
'''%run -i FL_vs_Centralized.py'''
# Out:
# '%run -i FL_vs_Centralized.py'

# %%
'''%run -i FL_vs_LocalOnly.py'''
# Out:
# '%run -i FL_vs_LocalOnly.py'
