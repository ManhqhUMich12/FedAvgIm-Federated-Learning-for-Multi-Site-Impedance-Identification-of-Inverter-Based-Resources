# %%
# ============================================================
# Cell 1 — Imports & global setup
# ============================================================

import os
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

import h5py
from scipy.io import loadmat
from sklearn.preprocessing import StandardScaler

import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader

import random

# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


# ============================================================
# Cell 2 — User configuration: file paths & label key
# ============================================================

LABEL_KEY = "Y_Y"  # Key name for labels inside .mat/.h5

TRAIN_FILE_PATHS = [
    "gfli1_impedance_dataset.mat",
    "gfli2_impedance_dataset.mat",
    "gfli3_impedance_dataset.mat",
    "gfli4_impedance_dataset.mat",
    "gfli5_impedance_dataset.mat",
    "gfli6_impedance_dataset.mat",
    "gfli7_impedance_dataset.mat",
    "gfli8_impedance_dataset.mat",
    "gfli9_impedance_dataset.mat",
]

TEST_FILE_PATHS = [
    "gfli1_test_impedance_dataset.mat",
    "gfli2_test_impedance_dataset.mat",
    "gfli3_test_impedance_dataset.mat",
    "gfli4_test_impedance_dataset.mat",
    "gfli5_test_impedance_dataset.mat",
    "gfli6_test_impedance_dataset.mat",
    "gfli7_test_impedance_dataset.mat",
    "gfli8_test_impedance_dataset.mat",
    "gfli9_test_impedance_dataset.mat",
]

print(f"#TRAIN files: {len(TRAIN_FILE_PATHS)}, #TEST files: {len(TEST_FILE_PATHS)}")


# ============================================================
# Cell 3 — IO helpers (.mat / .h5)
# ============================================================

def _fix_shape(arr, expected_cols=None):
    """
    Ensure 2D shape. If expected_cols is given, transpose when needed.
    """
    arr = np.asarray(arr)
    if arr.ndim == 1:
        arr = arr.reshape(-1, 1)
    if expected_cols is not None:
        if arr.shape[1] != expected_cols and arr.shape[0] == expected_cols:
            arr = arr.T
    return arr


def _extract_from_h5(f, label_key="Y_Y"):
    """
    Try to extract X (4 cols) and Y (8 cols) from an h5py.File handle.
    Expected structure:
      /Dataset/X, /Dataset/Y_Y (or label_key)
    Fallbacks:
      /X, /Y_Y at root.
    """
    def get_node(g, key):
        return g[key] if key in g else None

    # 1) common path: group 'Dataset' or 'dataset'
    g = get_node(f, "Dataset")
    if g is None:
        g = get_node(f, "dataset")

    if g is not None:
        X = _fix_shape(g["X"][()], expected_cols=4)
        if label_key in g:
            Ysrc = g[label_key]
        else:
            Ysrc = g.get("Y_Y")
        if Ysrc is None:
            raise KeyError("Neither label_key nor 'Y_Y' found under /Dataset")
        Y = _fix_shape(Ysrc[()], expected_cols=8)
        return X, Y

    # 2) fallback: variables at file root
    Xnode = get_node(f, "X")
    Ynode = get_node(f, label_key)
    if Ynode is None:
        Ynode = get_node(f, "Y_Y")

    if Xnode is None or Ynode is None:
        raise KeyError("Could not find X and Y in HDF5 file.")

    X = _fix_shape(Xnode[()], expected_cols=4)
    Y = _fix_shape(Ynode[()], expected_cols=8)
    return X, Y


def _extract_from_mat(d, label_key="Y_Y"):
    """
    Extract from dict returned by scipy.io.loadmat.
    Support:
      - struct Dataset with fields X, Y_Y (or label_key)
      - top-level X, Y_Y
    """
    d2 = {k: v for k, v in d.items() if not k.startswith("__")}

    # struct-like 'Dataset'
    if "Dataset" in d2:
        G = d2["Dataset"]
        if hasattr(G, "dtype") and G.dtype.names:
            fields = G.dtype.names

            def get_field(name):
                if name in fields:
                    val = G[name]
                    val = np.array(val).squeeze()
                    return val
                return None

            X_raw = get_field("X")
            if X_raw is None:
                raise KeyError("Field 'X' not found in Dataset struct.")
            X = _fix_shape(X_raw, expected_cols=4)

            Yraw = get_field(label_key)
            if Yraw is None:
                Yraw = get_field("Y_Y")
            if Yraw is None:
                raise KeyError("Neither label_key nor 'Y_Y' found in Dataset struct.")

            Y = _fix_shape(Yraw, expected_cols=8)
            return X, Y

    # top-level
    X = d2.get("X", None)
    Y = d2.get(label_key, None)
    if Y is None:
        Y = d2.get("Y_Y", None)

    if X is None or Y is None:
        raise KeyError("Could not find X and Y in MAT file (top-level).")

    X = _fix_shape(X, expected_cols=4)
    Y = _fix_shape(Y, expected_cols=8)
    return X, Y


def load_dataset_mat(path, label_key="Y_Y"):
    """
    Load one .mat dataset and return a dict:
      {
        'X': (N,4),
        'Y': (N,8),
        'family': 'GFMI'|'GFLI',
        'ibr': <filename stem>,
        'is_test': True|False
      }
    """
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"File not found: {path}")

    lower = path.name.lower()
    family = "GFMI" if "gfmi" in lower else "GFLI"
    is_test = "_test_" in lower
    ibr = path.stem

    # Try HDF5 first
    try:
        with h5py.File(path, "r") as f:
            X, Y = _extract_from_h5(f, label_key=label_key)
            return {"X": X, "Y": Y, "family": family, "ibr": ibr, "is_test": is_test}
    except Exception as e_h5:
        try:
            d = loadmat(str(path))
            X, Y = _extract_from_mat(d, label_key=label_key)
            return {"X": X, "Y": Y, "family": family, "ibr": ibr, "is_test": is_test}
        except Exception as e_mat:
            raise Exception(f"Error loading {path}: h5py-> {e_h5}; loadmat-> {e_mat}")


# ============================================================
# Cell 4 — Load TRAIN / TEST datasets & scaling
# ============================================================

loaded_tr, missing_tr = [], []
for fp in TRAIN_FILE_PATHS:
    try:
        d = load_dataset_mat(fp, LABEL_KEY)
        print(f"[TRAIN] Loaded: {fp} -> X:{d['X'].shape}, Y:{d['Y'].shape}, family={d['family']}")
        loaded_tr.append((fp, d))
    except Exception as e:
        print(f"[TRAIN] Error loading {fp}: {e}")
        missing_tr.append((fp, str(e)))

loaded_te, missing_te = [], []
for fp in TEST_FILE_PATHS:
    try:
        d = load_dataset_mat(fp, LABEL_KEY)
        print(f"[TEST ] Loaded: {fp} -> X:{d['X'].shape}, Y:{d['Y'].shape}, family={d['family']}")
        loaded_te.append((fp, d))
    except Exception as e:
        print(f"[TEST ] Error loading {fp}: {e}")
        missing_te.append((fp, str(e)))

print(f"\nTotal TRAIN loaded: {len(loaded_tr)}, TEST loaded: {len(loaded_te)}")

# Group by family
X_tr_gfmi, Y_tr_gfmi = [], []
X_tr_gfli, Y_tr_gfli = [], []

for fp, d in loaded_tr:
    if d["family"] == "GFMI":
        X_tr_gfmi.append(d["X"])
        Y_tr_gfmi.append(d["Y"])
    elif d["family"] == "GFLI":
        X_tr_gfli.append(d["X"])
        Y_tr_gfli.append(d["Y"])

if not X_tr_gfli:
    raise RuntimeError("Need at least one GFLI dataset in loaded_tr.")

# Stack GFLI to fit scaler
X_tr_gfli_all = np.vstack(X_tr_gfli)
Y_tr_gfli_all = np.vstack(Y_tr_gfli)

# Optional GFMI
if X_tr_gfmi:
    X_tr_gfmi_all = np.vstack(X_tr_gfmi)
    Y_tr_gfmi_all = np.vstack(Y_tr_gfmi)
    X_scaler_gfmi = StandardScaler().fit(X_tr_gfmi_all)
    Y_scaler_gfmi = StandardScaler().fit(Y_tr_gfmi_all)
else:
    X_scaler_gfmi = None
    Y_scaler_gfmi = None

# Scaler cho GFLI
X_scaler_gfli = StandardScaler().fit(X_tr_gfli_all)
Y_scaler_gfli = StandardScaler().fit(Y_tr_gfli_all)

input_dim  = X_tr_gfli_all.shape[1]  # 4
output_dim = Y_tr_gfli_all.shape[1]  # 8
print("Input dim:", input_dim, "| Output dim:", output_dim)


# ============================================================
# Cell 5 — Build clients & test sets
# ============================================================

clients_gfmi = []
clients_gfli = []
cid = 0

# GFMI clients (nếu có)
for fp, d in loaded_tr:
    fam = d["family"]
    X_raw = d["X"]
    Y_raw = d["Y"]

    if fam == "GFMI" and X_scaler_gfmi is not None:
        X_scaled = X_scaler_gfmi.transform(X_raw)
        Y_scaled = Y_scaler_gfmi.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32))
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32))
        ds = TensorDataset(X_t, Y_t)
        clients_gfmi.append({
            "id": cid,
            "name": Path(fp).stem,
            "family": fam,
            "dataset": ds,
            "n": X_t.shape[0],
        })
        cid += 1

# GFLI clients (chính cho FL)
for fp, d in loaded_tr:
    fam = d["family"]
    X_raw = d["X"]
    Y_raw = d["Y"]

    if fam == "GFLI":
        X_scaled = X_scaler_gfli.transform(X_raw)
        Y_scaled = Y_scaler_gfli.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32))
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32))
        ds = TensorDataset(X_t, Y_t)
        clients_gfli.append({
            "id": cid,
            "name": Path(fp).stem,
            "family": fam,
            "dataset": ds,
            "n": X_t.shape[0],
        })
        cid += 1

print("\nGFLI clients:")
for c in clients_gfli:
    print(f"  id={c['id']}, name={c['name']}, n={c['n']}")

# Build TEST sets (scaled, on device)
test_sets_gfmi = []
test_sets_gfli = []

for fp, d in loaded_te:
    fam = d["family"]
    X_raw = d["X"]
    Y_raw = d["Y"]

    if fam == "GFMI" and X_scaler_gfmi is not None:
        X_scaled = X_scaler_gfmi.transform(X_raw)
        Y_scaled = Y_scaler_gfmi.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32)).to(device)
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32)).to(device)
        test_sets_gfmi.append({
            "name": Path(fp).stem,
            "family": fam,
            "ibr": d["ibr"],
            "X": X_t,
            "Y": Y_t,
            "n": X_t.shape[0],
        })
    elif fam == "GFLI":
        X_scaled = X_scaler_gfli.transform(X_raw)
        Y_scaled = Y_scaler_gfli.transform(Y_raw)
        X_t = torch.from_numpy(X_scaled.astype(np.float32)).to(device)
        Y_t = torch.from_numpy(Y_scaled.astype(np.float32)).to(device)
        test_sets_gfli.append({
            "name": Path(fp).stem,
            "family": fam,
            "ibr": d["ibr"],
            "X": X_t,
            "Y": Y_t,
            "n": X_t.shape[0],
        })

print(f"\n#TEST GFMI: {len(test_sets_gfmi)}, #TEST GFLI: {len(test_sets_gfli)}")


# ============================================================
# Cell 6 — Model definitions (trunk + head)

class Trunk(nn.Module):
    def __init__(self, in_dim=4, hidden_dim=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)


class Head(nn.Module):
    def __init__(self, hidden_dim=64, out_dim=8):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(hidden_dim, 16),
            nn.ReLU(),
            nn.Linear(16, out_dim),
        )

    def forward(self, h):
        return self.net(h)


class FullModel(nn.Module):
    def __init__(self, trunk: Trunk, head: Head):
        super().__init__()
        self.trunk = trunk
        self.head = head

    def forward(self, x):
        h = self.trunk(x)
        y = self.head(h)
        return y


HIDDEN_GFLI = 32



# ============================================================
# Cell 7 — Standard FedAvg

ROUNDS_FL       = 200   # số round FL
LOCAL_EPOCHS_FL = 5
BATCH_SIZE_FL   = 512

LR_INIT_FL   = 1e-3
LR_DECAY1_FL = 700
LR_DECAY2_FL = 800
LR_FACTOR_FL = 0.1


def get_lr_for_round_fl(r: int) -> float:
    if r <= LR_DECAY1_FL:
        return LR_INIT_FL
    elif r <= LR_DECAY2_FL:
        return LR_INIT_FL * LR_FACTOR_FL
    else:
        return LR_INIT_FL * LR_FACTOR_FL * 0.5


def get_model_state_dict(model: FullModel):
    return {k: v.cpu().clone() for k, v in model.state_dict().items()}


def set_model_state_dict(model: FullModel, state_dict):
    model.load_state_dict(state_dict, strict=True)


def fedavg_models(model_states, sizes):
    total = float(sum(sizes))
    avg_state = {}
    for key in model_states[0].keys():
        avg_param = 0.0
        for sd, n in zip(model_states, sizes):
            avg_param += (n / total) * sd[key]
        avg_state[key] = avg_param
    return avg_state


def train_one_client_fullmodel(client,
                               global_model_state,
                               hidden_dim,
                               epochs=1,
                               batch_size=256,
                               lr=1e-3):
    trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
    head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
    model = FullModel(trunk, head).to(device)
    set_model_state_dict(model, global_model_state)
    model.train()

    ds = client["dataset"]
    loader = DataLoader(ds, batch_size=batch_size, shuffle=True)

    crit = nn.MSELoss()
    opt = torch.optim.Adam(model.parameters(), lr=lr)

    for _ in range(epochs):
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            y_pred = model(xb)
            loss = crit(y_pred, yb)
            loss.backward()
            opt.step()

    new_model_state = get_model_state_dict(model)
    return new_model_state


def evaluate_clients_full(global_model_state, clients, hidden_dim, batch_size=512):
    crit = nn.MSELoss()
    results = []

    for c in clients:
        trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
        head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
        model = FullModel(trunk, head).to(device)
        set_model_state_dict(model, global_model_state)
        model.eval()

        ds = c["dataset"]
        loader = DataLoader(ds, batch_size=batch_size, shuffle=False)

        total_loss, total_n = 0.0, 0
        with torch.no_grad():
            for xb, yb in loader:
                xb, yb = xb.to(device), yb.to(device)
                y_pred = model(xb)
                loss = crit(y_pred, yb) * xb.size(0)
                total_loss += loss.item()
                total_n += xb.size(0)

        mse = total_loss / total_n
        results.append((c["name"], mse))

    return results


def evaluate_tests_full(global_model_state, test_sets, hidden_dim, batch_size=512):
    crit = nn.MSELoss()
    results = []

    for ds in test_sets:
        test_name = ds["name"]

        trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
        head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
        model = FullModel(trunk, head).to(device)
        set_model_state_dict(model, global_model_state)
        model.eval()

        X_te = ds["X"]
        Y_te = ds["Y"]
        loader = DataLoader(TensorDataset(X_te, Y_te), batch_size=batch_size, shuffle=False)

        total_loss, total_n = 0.0, 0
        with torch.no_grad():
            for xb, yb in loader:
                xb, yb = xb.to(device), yb.to(device)
                y_pred = model(xb)
                loss = crit(y_pred, yb) * xb.size(0)
                total_loss += loss.item()
                total_n += xb.size(0)

        mse = total_loss / total_n
        results.append((test_name, mse))

    return results


def run_fedavg_full_gfli(clients, test_sets, hidden_dim, rounds):
    print(f"\n===== Standard FedAvg (full model) for GFLI (rounds={rounds}) =====")

    trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
    head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
    global_model = FullModel(trunk, head).to(device)
    global_model_state = get_model_state_dict(global_model)

    history = {
        "round": [],
        "train_mse_mean": [],
        "test_mse_mean": [],
        "train_mse_all": [],
        "test_mse_all": [],
    }

    for r in range(1, rounds + 1):
        model_states, sizes = [], []
        lr_round = get_lr_for_round_fl(r)

        for c in clients:
            new_state = train_one_client_fullmodel(
                client=c,
                global_model_state=global_model_state,
                hidden_dim=hidden_dim,
                epochs=LOCAL_EPOCHS_FL,
                batch_size=BATCH_SIZE_FL,
                lr=lr_round,
            )
            model_states.append(new_state)
            sizes.append(c["n"])

        global_model_state = fedavg_models(model_states, sizes)

        train_res = evaluate_clients_full(global_model_state, clients, hidden_dim)
        test_res  = evaluate_tests_full(global_model_state, test_sets, hidden_dim)

        train_mses = [m for _, m in train_res]
        test_mses  = [m for _, m in test_res] if test_res else []

        train_mse_mean = float(np.mean(train_mses))
        test_mse_mean  = float(np.mean(test_mses)) if test_mses else float("nan")

        history["round"].append(r)
        history["train_mse_mean"].append(train_mse_mean)
        history["test_mse_mean"].append(test_mse_mean)
        history["train_mse_all"].append(train_mses)
        history["test_mse_all"].append(test_mses)

        print(f"[FULL FedAvg] Round {r:03d} | "
              f"train MSE={train_mse_mean:.4e} | test MSE={test_mse_mean:.4e}")

    return global_model_state, history


# ============================================================
# Cell 8 — Helpers for Scenario 3 (subsample new client, fairness)
# ============================================================


def compute_fairness_jain(mse_list, eps=1e-8):
    """
    Jain fairness index trên 'utility' = 1/(MSE + eps).
    Giá trị trong [0, 1], càng gần 1 càng công bằng.
    """
    mse_arr = np.array(mse_list, dtype=np.float64)
    util = 1.0 / (mse_arr + eps)
    num = np.square(util.sum())
    den = len(util) * np.square(util).sum()
    return float(num / den)


# ============================================================
# ======================= Cell 9 — Scenario: Join vs NoJoin (2-step) =======================

def run_fedavg_pretrain_old(
    clients_old,
    test_sets,
    name_new_prefix,
    hidden_dim=HIDDEN_GFLI,
    rounds_pre=50,
    tag="FedAvg-Pretrain-OldOnly",
):
    """
    Bước 1: Pretrain FedAvg chỉ trên old clients từ round 1 -> rounds_pre.
    Vẫn evaluate test trên cả old + new (zero-shot new client).
    Trả về:
      - global_state tại round rounds_pre
      - history_pre: dict với keys ['round', 'test_mse_mean_old', 'test_mse_new']
    """
    print(f"\n===== {tag} | rounds_pre={rounds_pre} =====")

    # Khởi tạo global model (random)
    trunk = Trunk(in_dim=input_dim, hidden_dim=hidden_dim).to(device)
    head  = Head(hidden_dim=hidden_dim, out_dim=output_dim).to(device)
    global_model = FullModel(trunk, head).to(device)
    global_state = get_model_state_dict(global_model)

    history = {
        "round": [],
        "test_mse_mean_old": [],
        "test_mse_new": [],
    }

    for r in range(1, rounds_pre + 1):
        lr_round = get_lr_for_round_fl(r)

        # ---- Local training trên old clients ----
        model_states, sizes = [], []
        for c in clients_old:
            new_state = train_one_client_fullmodel(
                client=c,
                global_model_state=global_state,
                hidden_dim=hidden_dim,
                epochs=LOCAL_EPOCHS_FL,
                batch_size=BATCH_SIZE_FL,
                lr=lr_round,
            )
            model_states.append(new_state)
            sizes.append(c["n"])

        # FedAvg update
        global_state = fedavg_models(model_states, sizes)

        # ---- Evaluate TEST trên tất cả test-set (old + new) ----
        test_res_all = evaluate_tests_full(global_state, test_sets, hidden_dim)
        mse_old = []
        mse_new = None
        for tname, mse in test_res_all:
            if tname.lower().startswith(name_new_prefix):
                mse_new = float(mse)
            else:
                mse_old.append(float(mse))
        test_mse_mean_old = float(np.mean(mse_old)) if mse_old else float("nan")
        if mse_new is None:
            mse_new = float("nan")

        history["round"].append(r)
        history["test_mse_mean_old"].append(test_mse_mean_old)
        history["test_mse_new"].append(mse_new)

        print(f"[{tag}] Round {r:03d} | "
              f"test_old_mean={test_mse_mean_old:.4e} | "
              f"test_new={mse_new:.4e}")

    return global_state, history


def continue_fedavg_from_state(
    global_state_init,
    clients_old,
    client_new,
    test_sets,
    name_new_prefix,
    hidden_dim=HIDDEN_GFLI,
    start_round=50,
    rounds_total=ROUNDS_FL,
    join_new=False,
    history_pre=None,
    tag="FedAvg-Continue",
):
    """
    Bước 2: Từ global_state_init (round = start_round), tiếp tục train đến rounds_total.
    - join_new = False: chỉ old clients tham gia (NoJoin).
    - join_new = True: old + new client tham gia (Join).

    history_pre: dict history của giai đoạn pretrain (sẽ được copy và nối thêm).
    Trả về:
      - global_state cuối
      - history đầy đủ round 1..rounds_total
    """
    print(f"\n===== {tag} | join_new={join_new}, from round {start_round+1} to {rounds_total} =====")

    # Copy state để 2 scenario bắt đầu từ cùng checkpoint
    global_state = {k: v.clone() for k, v in global_state_init.items()}

    # Khởi tạo history là bản copy của pretrain
    if history_pre is not None:
        history = {k: list(v) for k, v in history_pre.items()}
    else:
        history = {"round": [], "test_mse_mean_old": [], "test_mse_new": []}

    # Danh sách client cho training nếu join_new
    all_clients = clients_old + [client_new]

    for r in range(start_round + 1, rounds_total + 1):
        lr_round = get_lr_for_round_fl(r)

        # ---- chọn client tham gia ----
        if join_new:
            active_clients = all_clients   # old + new
        else:
            active_clients = clients_old   # chỉ old

        # ---- Local training ----
        model_states, sizes = [], []
        for c in active_clients:
            new_state = train_one_client_fullmodel(
                client=c,
                global_model_state=global_state,
                hidden_dim=hidden_dim,
                epochs=LOCAL_EPOCHS_FL,
                batch_size=BATCH_SIZE_FL,
                lr=lr_round,
            )
            model_states.append(new_state)
            sizes.append(c["n"])

        # FedAvg update
        global_state = fedavg_models(model_states, sizes)

        # ---- Evaluate TEST trên tất cả test-set ----
        test_res_all = evaluate_tests_full(global_state, test_sets, hidden_dim)
        mse_old = []
        mse_new = None
        for tname, mse in test_res_all:
            if tname.lower().startswith(name_new_prefix):
                mse_new = float(mse)
            else:
                mse_old.append(float(mse))
        test_mse_mean_old = float(np.mean(mse_old)) if mse_old else float("nan")
        if mse_new is None:
            mse_new = float("nan")

        history["round"].append(r)
        history["test_mse_mean_old"].append(test_mse_mean_old)
        history["test_mse_new"].append(mse_new)

        print(f"[{tag}] Round {r:03d} | "
              f"test_old_mean={test_mse_mean_old:.4e} | "
              f"test_new={mse_new:.4e}")

    return global_state, history





# ============================================================
# ======================= Cell 10 — Chọn old/new client =======================

# Xác định new client: gfli1 (IBR1)
client_new_full = None
for c in clients_gfli:
    if c["name"].lower().startswith("gfli1"):
        client_new_full = c
        break

if client_new_full is None:
    raise RuntimeError("Không tìm thấy client có tên bắt đầu bằng 'gfli1' trong clients_gfli.")

# Old clients = các IBR còn lại (gfli2..gfli9)
clients_old = [c for c in clients_gfli if c["name"] != client_new_full["name"]]

print("\nOld clients:")
for c in clients_old:
    print(f"  {c['name']} (n={c['n']})")
print(f"New client (full): {client_new_full['name']} (n={client_new_full['n']})")

# Nếu muốn new client ít data, dùng frac < 1.0. Ví dụ: 0.1 hoặc 0.5
FRAC_NEW_DATA = 1.0  # <-- đổi 0.1 / 0.5 nếu muốn giảm data IBR1

def subsample_client(client, frac=0.1):
    ds = client["dataset"]
    X, Y = ds.tensors
    n = X.shape[0]
    k = max(1, int(n * frac))
    idx = torch.randperm(n)[:k]
    ds_small = TensorDataset(X[idx], Y[idx])
    new_client = dict(client)
    new_client["dataset"] = ds_small
    new_client["n"] = k
    return new_client

client_new = subsample_client(client_new_full, frac=FRAC_NEW_DATA)
print(f"New client (subsampled): {client_new['name']} (n={client_new['n']})")

# Prefix để nhận diện new client trong test set (vd "gfli1")
name_new_full   = client_new["name"].lower()
name_new_prefix = name_new_full.split("_")[0]




# ============================================================
# ======================= Cell 11 — Run 2-step & plot =======================

JOIN_ROUND = 50  # round tại đó checkpoint dùng để fork

# ---- Bước 1: Pretrain chỉ với old clients (round 1..JOIN_ROUND) ----
global_state_at_join, history_pre = run_fedavg_pretrain_old(
    clients_old=clients_old,
    test_sets=test_sets_gfli,
    name_new_prefix=name_new_prefix,
    hidden_dim=HIDDEN_GFLI,
    rounds_pre=JOIN_ROUND,
    tag="FedAvg-Pretrain-OldOnly",
)

# ---- Bước 2a: NoJoin — tiếp tục từ checkpoint, chỉ old clients ----
global_state_nojoin, hist_nojoin = continue_fedavg_from_state(
    global_state_init=global_state_at_join,
    clients_old=clients_old,
    client_new=client_new,
    test_sets=test_sets_gfli,
    name_new_prefix=name_new_prefix,
    hidden_dim=HIDDEN_GFLI,
    start_round=JOIN_ROUND,
    rounds_total=ROUNDS_FL,
    join_new=False,
    history_pre=history_pre,
    tag="FedAvg-NoJoin",
)

# ---- Bước 2b: Join — tiếp tục từ checkpoint, old + new ----
global_state_join, hist_join = continue_fedavg_from_state(
    global_state_init=global_state_at_join,
    clients_old=clients_old,
    client_new=client_new,
    test_sets=test_sets_gfli,
    name_new_prefix=name_new_prefix,
    hidden_dim=HIDDEN_GFLI,
    start_round=JOIN_ROUND,
    rounds_total=ROUNDS_FL,
    join_new=True,
    history_pre=history_pre,
    tag="FedAvg-Join",
)

rounds_axis = np.array(hist_join["round"])
# Out:
# Using device: cuda
# #TRAIN files: 9, #TEST files: 9
# [TRAIN] Loaded: gfli1_impedance_dataset.mat -> X:(390, 4), Y:(390, 8), family=GFLI
# [TRAIN] Loaded: gfli2_impedance_dataset.mat -> X:(330, 4), Y:(330, 8), family=GFLI
# [TRAIN] Loaded: gfli3_impedance_dataset.mat -> X:(330, 4), Y:(330, 8), family=GFLI
# [TRAIN] Loaded: gfli4_impedance_dataset.mat -> X:(100, 4), Y:(100, 8), family=GFLI
# [TRAIN] Loaded: gfli5_impedance_dataset.mat -> X:(330, 4), Y:(330, 8), family=GFLI
# [TRAIN] Loaded: gfli6_impedance_dataset.mat -> X:(220, 4), Y:(220, 8), family=GFLI
# [TRAIN] Loaded: gfli7_impedance_dataset.mat -> X:(140, 4), Y:(140, 8), family=GFLI
# [TRAIN] Loaded: gfli8_impedance_dataset.mat -> X:(180, 4), Y:(180, 8), family=GFLI
# [TRAIN] Loaded: gfli9_impedance_dataset.mat -> X:(40, 4), Y:(40, 8), family=GFLI
# [TEST ] Loaded: gfli1_test_impedance_dataset.mat -> X:(780, 4), Y:(780, 8), family=GFLI
# [TEST ] Loaded: gfli2_test_impedance_dataset.mat -> X:(660, 4), Y:(660, 8), family=GFLI
# [TEST ] Loaded: gfli3_test_impedance_dataset.mat -> X:(660, 4), Y:(660, 8), family=GFLI
# [TEST ] Loaded: gfli4_test_impedance_dataset.mat -> X:(200, 4), Y:(200, 8), family=GFLI
# [TEST ] Loaded: gfli5_test_impedance_dataset.mat -> X:(660, 4), Y:(660, 8), family=GFLI
# [TEST ] Loaded: gfli6_test_impedance_dataset.mat -> X:(440, 4), Y:(440, 8), family=GFLI
# [TEST ] Loaded: gfli7_test_impedance_dataset.mat -> X:(280, 4), Y:(280, 8), family=GFLI
# [TEST ] Loaded: gfli8_test_impedance_dataset.mat -> X:(342, 4), Y:(342, 8), family=GFLI
# [TEST ] Loaded: gfli9_test_impedance_dataset.mat -> X:(80, 4), Y:(80, 8), family=GFLI
#
# Total TRAIN loaded: 9, TEST loaded: 9
# Input dim: 4 | Output dim: 8
#
# GFLI clients:
#   id=0, name=gfli1_impedance_dataset, n=390
#   id=1, name=gfli2_impedance_dataset, n=330
#   id=2, name=gfli3_impedance_dataset, n=330
#   id=3, name=gfli4_impedance_dataset, n=100
#   id=4, name=gfli5_impedance_dataset, n=330
#   id=5, name=gfli6_impedance_dataset, n=220
#   id=6, name=gfli7_impedance_dataset, n=140
#   id=7, name=gfli8_impedance_dataset, n=180
#   id=8, name=gfli9_impedance_dataset, n=40
#
# #TEST GFMI: 0, #TEST GFLI: 9
#
# Old clients:
#   gfli2_impedance_dataset (n=330)
#   gfli3_impedance_dataset (n=330)
#   gfli4_impedance_dataset (n=100)
#   gfli5_impedance_dataset (n=330)
#   gfli6_impedance_dataset (n=220)
#   gfli7_impedance_dataset (n=140)
#   gfli8_impedance_dataset (n=180)
#   gfli9_impedance_dataset (n=40)
# New client (full): gfli1_impedance_dataset (n=390)
# New client (subsampled): gfli1_impedance_dataset (n=390)
#
# ===== FedAvg-Pretrain-OldOnly | rounds_pre=50 =====
# [FedAvg-Pretrain-OldOnly] Round 001 | test_old_mean=1.0977e+00 | test_new=8.2120e-01
# [FedAvg-Pretrain-OldOnly] Round 002 | test_old_mean=1.0854e+00 | test_new=8.1247e-01
# [FedAvg-Pretrain-OldOnly] Round 003 | test_old_mean=1.0727e+00 | test_new=8.0376e-01
# [FedAvg-Pretrain-OldOnly] Round 004 | test_old_mean=1.0598e+00 | test_new=7.9502e-01
# [FedAvg-Pretrain-OldOnly] Round 005 | test_old_mean=1.0461e+00 | test_new=7.8594e-01
# [FedAvg-Pretrain-OldOnly] Round 006 | test_old_mean=1.0317e+00 | test_new=7.7641e-01
# [FedAvg-Pretrain-OldOnly] Round 007 | test_old_mean=1.0168e+00 | test_new=7.6665e-01
# [FedAvg-Pretrain-OldOnly] Round 008 | test_old_mean=1.0017e+00 | test_new=7.5675e-01
# [FedAvg-Pretrain-OldOnly] Round 009 | test_old_mean=9.8659e-01 | test_new=7.4691e-01
# [FedAvg-Pretrain-OldOnly] Round 010 | test_old_mean=9.7169e-01 | test_new=7.3717e-01
# [FedAvg-Pretrain-OldOnly] Round 011 | test_old_mean=9.5708e-01 | test_new=7.2768e-01
# [FedAvg-Pretrain-OldOnly] Round 012 | test_old_mean=9.4296e-01 | test_new=7.1857e-01
# [FedAvg-Pretrain-OldOnly] Round 013 | test_old_mean=9.2944e-01 | test_new=7.1004e-01
# [FedAvg-Pretrain-OldOnly] Round 014 | test_old_mean=9.1656e-01 | test_new=7.0225e-01
# [FedAvg-Pretrain-OldOnly] Round 015 | test_old_mean=9.0448e-01 | test_new=6.9530e-01
# [FedAvg-Pretrain-OldOnly] Round 016 | test_old_mean=8.9346e-01 | test_new=6.8939e-01
# [FedAvg-Pretrain-OldOnly] Round 017 | test_old_mean=8.8335e-01 | test_new=6.8440e-01
# [FedAvg-Pretrain-OldOnly] Round 018 | test_old_mean=8.7425e-01 | test_new=6.8045e-01
# [FedAvg-Pretrain-OldOnly] Round 019 | test_old_mean=8.6608e-01 | test_new=6.7739e-01
# [FedAvg-Pretrain-OldOnly] Round 020 | test_old_mean=8.5905e-01 | test_new=6.7531e-01
# [FedAvg-Pretrain-OldOnly] Round 021 | test_old_mean=8.5316e-01 | test_new=6.7419e-01
# [FedAvg-Pretrain-OldOnly] Round 022 | test_old_mean=8.4840e-01 | test_new=6.7408e-01
# [FedAvg-Pretrain-OldOnly] Round 023 | test_old_mean=8.4465e-01 | test_new=6.7468e-01
# [FedAvg-Pretrain-OldOnly] Round 024 | test_old_mean=8.4192e-01 | test_new=6.7600e-01
# [FedAvg-Pretrain-OldOnly] Round 025 | test_old_mean=8.3992e-01 | test_new=6.7774e-01
# [FedAvg-Pretrain-OldOnly] Round 026 | test_old_mean=8.3841e-01 | test_new=6.7964e-01
# [FedAvg-Pretrain-OldOnly] Round 027 | test_old_mean=8.3696e-01 | test_new=6.8123e-01
# [FedAvg-Pretrain-OldOnly] Round 028 | test_old_mean=8.3548e-01 | test_new=6.8241e-01
# [FedAvg-Pretrain-OldOnly] Round 029 | test_old_mean=8.3417e-01 | test_new=6.8339e-01
# [FedAvg-Pretrain-OldOnly] Round 030 | test_old_mean=8.3293e-01 | test_new=6.8401e-01
# [FedAvg-Pretrain-OldOnly] Round 031 | test_old_mean=8.3162e-01 | test_new=6.8426e-01
# [FedAvg-Pretrain-OldOnly] Round 032 | test_old_mean=8.3007e-01 | test_new=6.8407e-01
# [FedAvg-Pretrain-OldOnly] Round 033 | test_old_mean=8.2829e-01 | test_new=6.8350e-01
# [FedAvg-Pretrain-OldOnly] Round 034 | test_old_mean=8.2636e-01 | test_new=6.8269e-01
# [FedAvg-Pretrain-OldOnly] Round 035 | test_old_mean=8.2419e-01 | test_new=6.8158e-01
# [FedAvg-Pretrain-OldOnly] Round 036 | test_old_mean=8.2184e-01 | test_new=6.8024e-01
# [FedAvg-Pretrain-OldOnly] Round 037 | test_old_mean=8.1939e-01 | test_new=6.7880e-01
# [FedAvg-Pretrain-OldOnly] Round 038 | test_old_mean=8.1687e-01 | test_new=6.7727e-01
# [FedAvg-Pretrain-OldOnly] Round 039 | test_old_mean=8.1430e-01 | test_new=6.7565e-01
# [FedAvg-Pretrain-OldOnly] Round 040 | test_old_mean=8.1164e-01 | test_new=6.7387e-01
# [FedAvg-Pretrain-OldOnly] Round 041 | test_old_mean=8.0894e-01 | test_new=6.7202e-01
# [FedAvg-Pretrain-OldOnly] Round 042 | test_old_mean=8.0612e-01 | test_new=6.7001e-01
# [FedAvg-Pretrain-OldOnly] Round 043 | test_old_mean=8.0305e-01 | test_new=6.6772e-01
# [FedAvg-Pretrain-OldOnly] Round 044 | test_old_mean=7.9978e-01 | test_new=6.6519e-01
# [FedAvg-Pretrain-OldOnly] Round 045 | test_old_mean=7.9641e-01 | test_new=6.6253e-01
# [FedAvg-Pretrain-OldOnly] Round 046 | test_old_mean=7.9291e-01 | test_new=6.5975e-01
# [FedAvg-Pretrain-OldOnly] Round 047 | test_old_mean=7.8923e-01 | test_new=6.5675e-01
# [FedAvg-Pretrain-OldOnly] Round 048 | test_old_mean=7.8544e-01 | test_new=6.5368e-01
# [FedAvg-Pretrain-OldOnly] Round 049 | test_old_mean=7.8152e-01 | test_new=6.5044e-01
# [FedAvg-Pretrain-OldOnly] Round 050 | test_old_mean=7.7742e-01 | test_new=6.4701e-01
#
# ===== FedAvg-NoJoin | join_new=False, from round 51 to 200 =====
# [FedAvg-NoJoin] Round 051 | test_old_mean=7.7313e-01 | test_new=6.4336e-01
# [FedAvg-NoJoin] Round 052 | test_old_mean=7.6862e-01 | test_new=6.3948e-01
# [FedAvg-NoJoin] Round 053 | test_old_mean=7.6393e-01 | test_new=6.3539e-01
# [FedAvg-NoJoin] Round 054 | test_old_mean=7.5903e-01 | test_new=6.3108e-01
# [FedAvg-NoJoin] Round 055 | test_old_mean=7.5399e-01 | test_new=6.2659e-01
# [FedAvg-NoJoin] Round 056 | test_old_mean=7.4875e-01 | test_new=6.2193e-01
# [FedAvg-NoJoin] Round 057 | test_old_mean=7.4331e-01 | test_new=6.1703e-01
# [FedAvg-NoJoin] Round 058 | test_old_mean=7.3766e-01 | test_new=6.1195e-01
# [FedAvg-NoJoin] Round 059 | test_old_mean=7.3187e-01 | test_new=6.0679e-01
# [FedAvg-NoJoin] Round 060 | test_old_mean=7.2595e-01 | test_new=6.0150e-01
# [FedAvg-NoJoin] Round 061 | test_old_mean=7.1986e-01 | test_new=5.9603e-01
# [FedAvg-NoJoin] Round 062 | test_old_mean=7.1363e-01 | test_new=5.9041e-01
# [FedAvg-NoJoin] Round 063 | test_old_mean=7.0730e-01 | test_new=5.8469e-01
# [FedAvg-NoJoin] Round 064 | test_old_mean=7.0090e-01 | test_new=5.7891e-01
# [FedAvg-NoJoin] Round 065 | test_old_mean=6.9446e-01 | test_new=5.7309e-01
# [FedAvg-NoJoin] Round 066 | test_old_mean=6.8792e-01 | test_new=5.6721e-01
# [FedAvg-NoJoin] Round 067 | test_old_mean=6.8128e-01 | test_new=5.6123e-01
# [FedAvg-NoJoin] Round 068 | test_old_mean=6.7450e-01 | test_new=5.5516e-01
# [FedAvg-NoJoin] Round 069 | test_old_mean=6.6764e-01 | test_new=5.4907e-01
# [FedAvg-NoJoin] Round 070 | test_old_mean=6.6070e-01 | test_new=5.4290e-01
# [FedAvg-NoJoin] Round 071 | test_old_mean=6.5363e-01 | test_new=5.3666e-01
# [FedAvg-NoJoin] Round 072 | test_old_mean=6.4637e-01 | test_new=5.3020e-01
# [FedAvg-NoJoin] Round 073 | test_old_mean=6.3904e-01 | test_new=5.2370e-01
# [FedAvg-NoJoin] Round 074 | test_old_mean=6.3162e-01 | test_new=5.1708e-01
# [FedAvg-NoJoin] Round 075 | test_old_mean=6.2406e-01 | test_new=5.1034e-01
# [FedAvg-NoJoin] Round 076 | test_old_mean=6.1639e-01 | test_new=5.0349e-01
# [FedAvg-NoJoin] Round 077 | test_old_mean=6.0861e-01 | test_new=4.9656e-01
# [FedAvg-NoJoin] Round 078 | test_old_mean=6.0071e-01 | test_new=4.8950e-01
# [FedAvg-NoJoin] Round 079 | test_old_mean=5.9273e-01 | test_new=4.8237e-01
# [FedAvg-NoJoin] Round 080 | test_old_mean=5.8459e-01 | test_new=4.7508e-01
# [FedAvg-NoJoin] Round 081 | test_old_mean=5.7635e-01 | test_new=4.6774e-01
# [FedAvg-NoJoin] Round 082 | test_old_mean=5.6802e-01 | test_new=4.6032e-01
# [FedAvg-NoJoin] Round 083 | test_old_mean=5.5963e-01 | test_new=4.5285e-01
# [FedAvg-NoJoin] Round 084 | test_old_mean=5.5116e-01 | test_new=4.4535e-01
# [FedAvg-NoJoin] Round 085 | test_old_mean=5.4258e-01 | test_new=4.3777e-01
# [FedAvg-NoJoin] Round 086 | test_old_mean=5.3394e-01 | test_new=4.3012e-01
# [FedAvg-NoJoin] Round 087 | test_old_mean=5.2523e-01 | test_new=4.2244e-01
# [FedAvg-NoJoin] Round 088 | test_old_mean=5.1649e-01 | test_new=4.1483e-01
# [FedAvg-NoJoin] Round 089 | test_old_mean=5.0772e-01 | test_new=4.0723e-01
# [FedAvg-NoJoin] Round 090 | test_old_mean=4.9897e-01 | test_new=3.9972e-01
# [FedAvg-NoJoin] Round 091 | test_old_mean=4.9025e-01 | test_new=3.9224e-01
# [FedAvg-NoJoin] Round 092 | test_old_mean=4.8152e-01 | test_new=3.8480e-01
# [FedAvg-NoJoin] Round 093 | test_old_mean=4.7282e-01 | test_new=3.7742e-01
# [FedAvg-NoJoin] Round 094 | test_old_mean=4.6407e-01 | test_new=3.7006e-01
# [FedAvg-NoJoin] Round 095 | test_old_mean=4.5536e-01 | test_new=3.6279e-01
# [FedAvg-NoJoin] Round 096 | test_old_mean=4.4665e-01 | test_new=3.5557e-01
# [FedAvg-NoJoin] Round 097 | test_old_mean=4.3801e-01 | test_new=3.4845e-01
# [FedAvg-NoJoin] Round 098 | test_old_mean=4.2938e-01 | test_new=3.4138e-01
# [FedAvg-NoJoin] Round 099 | test_old_mean=4.2074e-01 | test_new=3.3431e-01
# [FedAvg-NoJoin] Round 100 | test_old_mean=4.1210e-01 | test_new=3.2732e-01
# [FedAvg-NoJoin] Round 101 | test_old_mean=4.0346e-01 | test_new=3.2033e-01
# [FedAvg-NoJoin] Round 102 | test_old_mean=3.9485e-01 | test_new=3.1338e-01
# [FedAvg-NoJoin] Round 103 | test_old_mean=3.8628e-01 | test_new=3.0650e-01
# [FedAvg-NoJoin] Round 104 | test_old_mean=3.7772e-01 | test_new=2.9965e-01
# [FedAvg-NoJoin] Round 105 | test_old_mean=3.6917e-01 | test_new=2.9282e-01
# [FedAvg-NoJoin] Round 106 | test_old_mean=3.6074e-01 | test_new=2.8612e-01
# [FedAvg-NoJoin] Round 107 | test_old_mean=3.5245e-01 | test_new=2.7955e-01
# [FedAvg-NoJoin] Round 108 | test_old_mean=3.4429e-01 | test_new=2.7314e-01
# [FedAvg-NoJoin] Round 109 | test_old_mean=3.3629e-01 | test_new=2.6687e-01
# [FedAvg-NoJoin] Round 110 | test_old_mean=3.2846e-01 | test_new=2.6078e-01
# [FedAvg-NoJoin] Round 111 | test_old_mean=3.2080e-01 | test_new=2.5488e-01
# [FedAvg-NoJoin] Round 112 | test_old_mean=3.1330e-01 | test_new=2.4917e-01
# [FedAvg-NoJoin] Round 113 | test_old_mean=3.0599e-01 | test_new=2.4361e-01
# [FedAvg-NoJoin] Round 114 | test_old_mean=2.9882e-01 | test_new=2.3820e-01
# [FedAvg-NoJoin] Round 115 | test_old_mean=2.9182e-01 | test_new=2.3292e-01
# [FedAvg-NoJoin] Round 116 | test_old_mean=2.8497e-01 | test_new=2.2778e-01
# [FedAvg-NoJoin] Round 117 | test_old_mean=2.7826e-01 | test_new=2.2278e-01
# [FedAvg-NoJoin] Round 118 | test_old_mean=2.7169e-01 | test_new=2.1789e-01
# [FedAvg-NoJoin] Round 119 | test_old_mean=2.6531e-01 | test_new=2.1316e-01
# [FedAvg-NoJoin] Round 120 | test_old_mean=2.5912e-01 | test_new=2.0857e-01
# [FedAvg-NoJoin] Round 121 | test_old_mean=2.5308e-01 | test_new=2.0413e-01
# [FedAvg-NoJoin] Round 122 | test_old_mean=2.4722e-01 | test_new=1.9981e-01
# [FedAvg-NoJoin] Round 123 | test_old_mean=2.4153e-01 | test_new=1.9562e-01
# [FedAvg-NoJoin] Round 124 | test_old_mean=2.3601e-01 | test_new=1.9159e-01
# [FedAvg-NoJoin] Round 125 | test_old_mean=2.3062e-01 | test_new=1.8763e-01
# [FedAvg-NoJoin] Round 126 | test_old_mean=2.2541e-01 | test_new=1.8384e-01
# [FedAvg-NoJoin] Round 127 | test_old_mean=2.2036e-01 | test_new=1.8015e-01
# [FedAvg-NoJoin] Round 128 | test_old_mean=2.1548e-01 | test_new=1.7663e-01
# [FedAvg-NoJoin] Round 129 | test_old_mean=2.1077e-01 | test_new=1.7322e-01
# [FedAvg-NoJoin] Round 130 | test_old_mean=2.0618e-01 | test_new=1.6996e-01
# [FedAvg-NoJoin] Round 131 | test_old_mean=2.0170e-01 | test_new=1.6678e-01
# [FedAvg-NoJoin] Round 132 | test_old_mean=1.9735e-01 | test_new=1.6369e-01
# [FedAvg-NoJoin] Round 133 | test_old_mean=1.9313e-01 | test_new=1.6069e-01
# [FedAvg-NoJoin] Round 134 | test_old_mean=1.8902e-01 | test_new=1.5778e-01
# [FedAvg-NoJoin] Round 135 | test_old_mean=1.8503e-01 | test_new=1.5496e-01
# [FedAvg-NoJoin] Round 136 | test_old_mean=1.8115e-01 | test_new=1.5222e-01
# [FedAvg-NoJoin] Round 137 | test_old_mean=1.7739e-01 | test_new=1.4957e-01
# [FedAvg-NoJoin] Round 138 | test_old_mean=1.7374e-01 | test_new=1.4701e-01
# [FedAvg-NoJoin] Round 139 | test_old_mean=1.7017e-01 | test_new=1.4451e-01
# [FedAvg-NoJoin] Round 140 | test_old_mean=1.6676e-01 | test_new=1.4212e-01
# [FedAvg-NoJoin] Round 141 | test_old_mean=1.6342e-01 | test_new=1.3980e-01
# [FedAvg-NoJoin] Round 142 | test_old_mean=1.6020e-01 | test_new=1.3753e-01
# [FedAvg-NoJoin] Round 143 | test_old_mean=1.5706e-01 | test_new=1.3533e-01
# [FedAvg-NoJoin] Round 144 | test_old_mean=1.5397e-01 | test_new=1.3313e-01
# [FedAvg-NoJoin] Round 145 | test_old_mean=1.5097e-01 | test_new=1.3095e-01
# [FedAvg-NoJoin] Round 146 | test_old_mean=1.4805e-01 | test_new=1.2884e-01
# [FedAvg-NoJoin] Round 147 | test_old_mean=1.4523e-01 | test_new=1.2680e-01
# [FedAvg-NoJoin] Round 148 | test_old_mean=1.4248e-01 | test_new=1.2478e-01
# [FedAvg-NoJoin] Round 149 | test_old_mean=1.3980e-01 | test_new=1.2278e-01
# [FedAvg-NoJoin] Round 150 | test_old_mean=1.3719e-01 | test_new=1.2077e-01
# [FedAvg-NoJoin] Round 151 | test_old_mean=1.3462e-01 | test_new=1.1881e-01
# [FedAvg-NoJoin] Round 152 | test_old_mean=1.3213e-01 | test_new=1.1691e-01
# [FedAvg-NoJoin] Round 153 | test_old_mean=1.2970e-01 | test_new=1.1505e-01
# [FedAvg-NoJoin] Round 154 | test_old_mean=1.2738e-01 | test_new=1.1328e-01
# [FedAvg-NoJoin] Round 155 | test_old_mean=1.2513e-01 | test_new=1.1156e-01
# [FedAvg-NoJoin] Round 156 | test_old_mean=1.2295e-01 | test_new=1.0987e-01
# [FedAvg-NoJoin] Round 157 | test_old_mean=1.2086e-01 | test_new=1.0822e-01
# [FedAvg-NoJoin] Round 158 | test_old_mean=1.1882e-01 | test_new=1.0663e-01
# [FedAvg-NoJoin] Round 159 | test_old_mean=1.1685e-01 | test_new=1.0505e-01
# [FedAvg-NoJoin] Round 160 | test_old_mean=1.1494e-01 | test_new=1.0350e-01
# [FedAvg-NoJoin] Round 161 | test_old_mean=1.1311e-01 | test_new=1.0205e-01
# [FedAvg-NoJoin] Round 162 | test_old_mean=1.1131e-01 | test_new=1.0061e-01
# [FedAvg-NoJoin] Round 163 | test_old_mean=1.0956e-01 | test_new=9.9229e-02
# [FedAvg-NoJoin] Round 164 | test_old_mean=1.0788e-01 | test_new=9.7888e-02
# [FedAvg-NoJoin] Round 165 | test_old_mean=1.0621e-01 | test_new=9.6566e-02
# [FedAvg-NoJoin] Round 166 | test_old_mean=1.0458e-01 | test_new=9.5259e-02
# [FedAvg-NoJoin] Round 167 | test_old_mean=1.0300e-01 | test_new=9.3990e-02
# [FedAvg-NoJoin] Round 168 | test_old_mean=1.0147e-01 | test_new=9.2761e-02
# [FedAvg-NoJoin] Round 169 | test_old_mean=9.9961e-02 | test_new=9.1569e-02
# [FedAvg-NoJoin] Round 170 | test_old_mean=9.8511e-02 | test_new=9.0413e-02
# [FedAvg-NoJoin] Round 171 | test_old_mean=9.7088e-02 | test_new=8.9291e-02
# [FedAvg-NoJoin] Round 172 | test_old_mean=9.5710e-02 | test_new=8.8201e-02
# [FedAvg-NoJoin] Round 173 | test_old_mean=9.4388e-02 | test_new=8.7171e-02
# [FedAvg-NoJoin] Round 174 | test_old_mean=9.3106e-02 | test_new=8.6149e-02
# [FedAvg-NoJoin] Round 175 | test_old_mean=9.1895e-02 | test_new=8.5200e-02
# [FedAvg-NoJoin] Round 176 | test_old_mean=9.0752e-02 | test_new=8.4304e-02
# [FedAvg-NoJoin] Round 177 | test_old_mean=8.9629e-02 | test_new=8.3410e-02
# [FedAvg-NoJoin] Round 178 | test_old_mean=8.8532e-02 | test_new=8.2543e-02
# [FedAvg-NoJoin] Round 179 | test_old_mean=8.7459e-02 | test_new=8.1703e-02
# [FedAvg-NoJoin] Round 180 | test_old_mean=8.6408e-02 | test_new=8.0867e-02
# [FedAvg-NoJoin] Round 181 | test_old_mean=8.5396e-02 | test_new=8.0076e-02
# [FedAvg-NoJoin] Round 182 | test_old_mean=8.4422e-02 | test_new=7.9314e-02
# [FedAvg-NoJoin] Round 183 | test_old_mean=8.3506e-02 | test_new=7.8598e-02
# [FedAvg-NoJoin] Round 184 | test_old_mean=8.2595e-02 | test_new=7.7875e-02
# [FedAvg-NoJoin] Round 185 | test_old_mean=8.1694e-02 | test_new=7.7163e-02
# [FedAvg-NoJoin] Round 186 | test_old_mean=8.0821e-02 | test_new=7.6473e-02
# [FedAvg-NoJoin] Round 187 | test_old_mean=7.9959e-02 | test_new=7.5787e-02
# [FedAvg-NoJoin] Round 188 | test_old_mean=7.9135e-02 | test_new=7.5131e-02
# [FedAvg-NoJoin] Round 189 | test_old_mean=7.8333e-02 | test_new=7.4487e-02
# [FedAvg-NoJoin] Round 190 | test_old_mean=7.7556e-02 | test_new=7.3857e-02
# [FedAvg-NoJoin] Round 191 | test_old_mean=7.6797e-02 | test_new=7.3239e-02
# [FedAvg-NoJoin] Round 192 | test_old_mean=7.6066e-02 | test_new=7.2629e-02
# [FedAvg-NoJoin] Round 193 | test_old_mean=7.5348e-02 | test_new=7.2033e-02
# [FedAvg-NoJoin] Round 194 | test_old_mean=7.4649e-02 | test_new=7.1443e-02
# [FedAvg-NoJoin] Round 195 | test_old_mean=7.3980e-02 | test_new=7.0879e-02
# [FedAvg-NoJoin] Round 196 | test_old_mean=7.3328e-02 | test_new=7.0328e-02
# [FedAvg-NoJoin] Round 197 | test_old_mean=7.2716e-02 | test_new=6.9809e-02
# [FedAvg-NoJoin] Round 198 | test_old_mean=7.2097e-02 | test_new=6.9276e-02
# [FedAvg-NoJoin] Round 199 | test_old_mean=7.1493e-02 | test_new=6.8754e-02
# [FedAvg-NoJoin] Round 200 | test_old_mean=7.0904e-02 | test_new=6.8241e-02
#
# ===== FedAvg-Join | join_new=True, from round 51 to 200 =====
# [FedAvg-Join] Round 051 | test_old_mean=7.6728e-01 | test_new=6.3448e-01
# [FedAvg-Join] Round 052 | test_old_mean=7.5796e-01 | test_new=6.2358e-01
# [FedAvg-Join] Round 053 | test_old_mean=7.4925e-01 | test_new=6.1384e-01
# [FedAvg-Join] Round 054 | test_old_mean=7.4099e-01 | test_new=6.0492e-01
# [FedAvg-Join] Round 055 | test_old_mean=7.3301e-01 | test_new=5.9654e-01
# [FedAvg-Join] Round 056 | test_old_mean=7.2525e-01 | test_new=5.8862e-01
# [FedAvg-Join] Round 057 | test_old_mean=7.1768e-01 | test_new=5.8105e-01
# [FedAvg-Join] Round 058 | test_old_mean=7.1023e-01 | test_new=5.7375e-01
# [FedAvg-Join] Round 059 | test_old_mean=7.0281e-01 | test_new=5.6662e-01
# [FedAvg-Join] Round 060 | test_old_mean=6.9542e-01 | test_new=5.5959e-01
# [FedAvg-Join] Round 061 | test_old_mean=6.8807e-01 | test_new=5.5267e-01
# [FedAvg-Join] Round 062 | test_old_mean=6.8074e-01 | test_new=5.4585e-01
# [FedAvg-Join] Round 063 | test_old_mean=6.7337e-01 | test_new=5.3910e-01
# [FedAvg-Join] Round 064 | test_old_mean=6.6598e-01 | test_new=5.3244e-01
# [FedAvg-Join] Round 065 | test_old_mean=6.5853e-01 | test_new=5.2581e-01
# [FedAvg-Join] Round 066 | test_old_mean=6.5102e-01 | test_new=5.1925e-01
# [FedAvg-Join] Round 067 | test_old_mean=6.4348e-01 | test_new=5.1274e-01
# [FedAvg-Join] Round 068 | test_old_mean=6.3589e-01 | test_new=5.0626e-01
# [FedAvg-Join] Round 069 | test_old_mean=6.2816e-01 | test_new=4.9971e-01
# [FedAvg-Join] Round 070 | test_old_mean=6.2039e-01 | test_new=4.9319e-01
# [FedAvg-Join] Round 071 | test_old_mean=6.1257e-01 | test_new=4.8661e-01
# [FedAvg-Join] Round 072 | test_old_mean=6.0470e-01 | test_new=4.8003e-01
# [FedAvg-Join] Round 073 | test_old_mean=5.9678e-01 | test_new=4.7347e-01
# [FedAvg-Join] Round 074 | test_old_mean=5.8883e-01 | test_new=4.6692e-01
# [FedAvg-Join] Round 075 | test_old_mean=5.8081e-01 | test_new=4.6030e-01
# [FedAvg-Join] Round 076 | test_old_mean=5.7272e-01 | test_new=4.5364e-01
# [FedAvg-Join] Round 077 | test_old_mean=5.6459e-01 | test_new=4.4692e-01
# [FedAvg-Join] Round 078 | test_old_mean=5.5639e-01 | test_new=4.4014e-01
# [FedAvg-Join] Round 079 | test_old_mean=5.4815e-01 | test_new=4.3337e-01
# [FedAvg-Join] Round 080 | test_old_mean=5.3989e-01 | test_new=4.2659e-01
# [FedAvg-Join] Round 081 | test_old_mean=5.3158e-01 | test_new=4.1980e-01
# [FedAvg-Join] Round 082 | test_old_mean=5.2325e-01 | test_new=4.1298e-01
# [FedAvg-Join] Round 083 | test_old_mean=5.1492e-01 | test_new=4.0615e-01
# [FedAvg-Join] Round 084 | test_old_mean=5.0656e-01 | test_new=3.9931e-01
# [FedAvg-Join] Round 085 | test_old_mean=4.9819e-01 | test_new=3.9246e-01
# [FedAvg-Join] Round 086 | test_old_mean=4.8980e-01 | test_new=3.8566e-01
# [FedAvg-Join] Round 087 | test_old_mean=4.8138e-01 | test_new=3.7885e-01
# [FedAvg-Join] Round 088 | test_old_mean=4.7295e-01 | test_new=3.7199e-01
# [FedAvg-Join] Round 089 | test_old_mean=4.6452e-01 | test_new=3.6514e-01
# [FedAvg-Join] Round 090 | test_old_mean=4.5611e-01 | test_new=3.5834e-01
# [FedAvg-Join] Round 091 | test_old_mean=4.4773e-01 | test_new=3.5159e-01
# [FedAvg-Join] Round 092 | test_old_mean=4.3938e-01 | test_new=3.4485e-01
# [FedAvg-Join] Round 093 | test_old_mean=4.3104e-01 | test_new=3.3814e-01
# [FedAvg-Join] Round 094 | test_old_mean=4.2277e-01 | test_new=3.3151e-01
# [FedAvg-Join] Round 095 | test_old_mean=4.1452e-01 | test_new=3.2488e-01
# [FedAvg-Join] Round 096 | test_old_mean=4.0632e-01 | test_new=3.1828e-01
# [FedAvg-Join] Round 097 | test_old_mean=3.9814e-01 | test_new=3.1178e-01
# [FedAvg-Join] Round 098 | test_old_mean=3.9000e-01 | test_new=3.0531e-01
# [FedAvg-Join] Round 099 | test_old_mean=3.8189e-01 | test_new=2.9888e-01
# [FedAvg-Join] Round 100 | test_old_mean=3.7383e-01 | test_new=2.9250e-01
# [FedAvg-Join] Round 101 | test_old_mean=3.6582e-01 | test_new=2.8619e-01
# [FedAvg-Join] Round 102 | test_old_mean=3.5789e-01 | test_new=2.8000e-01
# [FedAvg-Join] Round 103 | test_old_mean=3.5003e-01 | test_new=2.7385e-01
# [FedAvg-Join] Round 104 | test_old_mean=3.4219e-01 | test_new=2.6778e-01
# [FedAvg-Join] Round 105 | test_old_mean=3.3446e-01 | test_new=2.6179e-01
# [FedAvg-Join] Round 106 | test_old_mean=3.2688e-01 | test_new=2.5591e-01
# [FedAvg-Join] Round 107 | test_old_mean=3.1941e-01 | test_new=2.5016e-01
# [FedAvg-Join] Round 108 | test_old_mean=3.1209e-01 | test_new=2.4453e-01
# [FedAvg-Join] Round 109 | test_old_mean=3.0487e-01 | test_new=2.3899e-01
# [FedAvg-Join] Round 110 | test_old_mean=2.9780e-01 | test_new=2.3361e-01
# [FedAvg-Join] Round 111 | test_old_mean=2.9084e-01 | test_new=2.2829e-01
# [FedAvg-Join] Round 112 | test_old_mean=2.8398e-01 | test_new=2.2307e-01
# [FedAvg-Join] Round 113 | test_old_mean=2.7723e-01 | test_new=2.1796e-01
# [FedAvg-Join] Round 114 | test_old_mean=2.7059e-01 | test_new=2.1296e-01
# [FedAvg-Join] Round 115 | test_old_mean=2.6409e-01 | test_new=2.0808e-01
# [FedAvg-Join] Round 116 | test_old_mean=2.5769e-01 | test_new=2.0328e-01
# [FedAvg-Join] Round 117 | test_old_mean=2.5140e-01 | test_new=1.9858e-01
# [FedAvg-Join] Round 118 | test_old_mean=2.4520e-01 | test_new=1.9398e-01
# [FedAvg-Join] Round 119 | test_old_mean=2.3914e-01 | test_new=1.8953e-01
# [FedAvg-Join] Round 120 | test_old_mean=2.3325e-01 | test_new=1.8523e-01
# [FedAvg-Join] Round 121 | test_old_mean=2.2752e-01 | test_new=1.8106e-01
# [FedAvg-Join] Round 122 | test_old_mean=2.2189e-01 | test_new=1.7696e-01
# [FedAvg-Join] Round 123 | test_old_mean=2.1637e-01 | test_new=1.7294e-01
# [FedAvg-Join] Round 124 | test_old_mean=2.1098e-01 | test_new=1.6902e-01
# [FedAvg-Join] Round 125 | test_old_mean=2.0572e-01 | test_new=1.6517e-01
# [FedAvg-Join] Round 126 | test_old_mean=2.0055e-01 | test_new=1.6134e-01
# [FedAvg-Join] Round 127 | test_old_mean=1.9549e-01 | test_new=1.5760e-01
# [FedAvg-Join] Round 128 | test_old_mean=1.9055e-01 | test_new=1.5390e-01
# [FedAvg-Join] Round 129 | test_old_mean=1.8574e-01 | test_new=1.5028e-01
# [FedAvg-Join] Round 130 | test_old_mean=1.8104e-01 | test_new=1.4675e-01
# [FedAvg-Join] Round 131 | test_old_mean=1.7642e-01 | test_new=1.4327e-01
# [FedAvg-Join] Round 132 | test_old_mean=1.7190e-01 | test_new=1.3984e-01
# [FedAvg-Join] Round 133 | test_old_mean=1.6747e-01 | test_new=1.3648e-01
# [FedAvg-Join] Round 134 | test_old_mean=1.6313e-01 | test_new=1.3317e-01
# [FedAvg-Join] Round 135 | test_old_mean=1.5890e-01 | test_new=1.2995e-01
# [FedAvg-Join] Round 136 | test_old_mean=1.5474e-01 | test_new=1.2677e-01
# [FedAvg-Join] Round 137 | test_old_mean=1.5066e-01 | test_new=1.2366e-01
# [FedAvg-Join] Round 138 | test_old_mean=1.4668e-01 | test_new=1.2061e-01
# [FedAvg-Join] Round 139 | test_old_mean=1.4282e-01 | test_new=1.1767e-01
# [FedAvg-Join] Round 140 | test_old_mean=1.3905e-01 | test_new=1.1481e-01
# [FedAvg-Join] Round 141 | test_old_mean=1.3541e-01 | test_new=1.1209e-01
# [FedAvg-Join] Round 142 | test_old_mean=1.3186e-01 | test_new=1.0943e-01
# [FedAvg-Join] Round 143 | test_old_mean=1.2845e-01 | test_new=1.0690e-01
# [FedAvg-Join] Round 144 | test_old_mean=1.2516e-01 | test_new=1.0447e-01
# [FedAvg-Join] Round 145 | test_old_mean=1.2200e-01 | test_new=1.0217e-01
# [FedAvg-Join] Round 146 | test_old_mean=1.1896e-01 | test_new=9.9955e-02
# [FedAvg-Join] Round 147 | test_old_mean=1.1604e-01 | test_new=9.7853e-02
# [FedAvg-Join] Round 148 | test_old_mean=1.1325e-01 | test_new=9.5847e-02
# [FedAvg-Join] Round 149 | test_old_mean=1.1057e-01 | test_new=9.3908e-02
# [FedAvg-Join] Round 150 | test_old_mean=1.0797e-01 | test_new=9.2046e-02
# [FedAvg-Join] Round 151 | test_old_mean=1.0549e-01 | test_new=9.0276e-02
# [FedAvg-Join] Round 152 | test_old_mean=1.0311e-01 | test_new=8.8587e-02
# [FedAvg-Join] Round 153 | test_old_mean=1.0084e-01 | test_new=8.6976e-02
# [FedAvg-Join] Round 154 | test_old_mean=9.8658e-02 | test_new=8.5402e-02
# [FedAvg-Join] Round 155 | test_old_mean=9.6565e-02 | test_new=8.3896e-02
# [FedAvg-Join] Round 156 | test_old_mean=9.4552e-02 | test_new=8.2450e-02
# [FedAvg-Join] Round 157 | test_old_mean=9.2670e-02 | test_new=8.1105e-02
# [FedAvg-Join] Round 158 | test_old_mean=9.0845e-02 | test_new=7.9778e-02
# [FedAvg-Join] Round 159 | test_old_mean=8.9096e-02 | test_new=7.8525e-02
# [FedAvg-Join] Round 160 | test_old_mean=8.7421e-02 | test_new=7.7305e-02
# [FedAvg-Join] Round 161 | test_old_mean=8.5793e-02 | test_new=7.6137e-02
# [FedAvg-Join] Round 162 | test_old_mean=8.4229e-02 | test_new=7.4990e-02
# [FedAvg-Join] Round 163 | test_old_mean=8.2729e-02 | test_new=7.3899e-02
# [FedAvg-Join] Round 164 | test_old_mean=8.1279e-02 | test_new=7.2850e-02
# [FedAvg-Join] Round 165 | test_old_mean=7.9877e-02 | test_new=7.1814e-02
# [FedAvg-Join] Round 166 | test_old_mean=7.8503e-02 | test_new=7.0807e-02
# [FedAvg-Join] Round 167 | test_old_mean=7.7201e-02 | test_new=6.9838e-02
# [FedAvg-Join] Round 168 | test_old_mean=7.5966e-02 | test_new=6.8930e-02
# [FedAvg-Join] Round 169 | test_old_mean=7.4765e-02 | test_new=6.8015e-02
# [FedAvg-Join] Round 170 | test_old_mean=7.3619e-02 | test_new=6.7145e-02
# [FedAvg-Join] Round 171 | test_old_mean=7.2512e-02 | test_new=6.6284e-02
# [FedAvg-Join] Round 172 | test_old_mean=7.1437e-02 | test_new=6.5450e-02
# [FedAvg-Join] Round 173 | test_old_mean=7.0413e-02 | test_new=6.4663e-02
# [FedAvg-Join] Round 174 | test_old_mean=6.9421e-02 | test_new=6.3894e-02
# [FedAvg-Join] Round 175 | test_old_mean=6.8435e-02 | test_new=6.3127e-02
# [FedAvg-Join] Round 176 | test_old_mean=6.7480e-02 | test_new=6.2372e-02
# [FedAvg-Join] Round 177 | test_old_mean=6.6547e-02 | test_new=6.1644e-02
# [FedAvg-Join] Round 178 | test_old_mean=6.5647e-02 | test_new=6.0934e-02
# [FedAvg-Join] Round 179 | test_old_mean=6.4779e-02 | test_new=6.0243e-02
# [FedAvg-Join] Round 180 | test_old_mean=6.3921e-02 | test_new=5.9576e-02
# [FedAvg-Join] Round 181 | test_old_mean=6.3081e-02 | test_new=5.8933e-02
# [FedAvg-Join] Round 182 | test_old_mean=6.2273e-02 | test_new=5.8322e-02
# [FedAvg-Join] Round 183 | test_old_mean=6.1460e-02 | test_new=5.7711e-02
# [FedAvg-Join] Round 184 | test_old_mean=6.0678e-02 | test_new=5.7132e-02
# [FedAvg-Join] Round 185 | test_old_mean=5.9917e-02 | test_new=5.6572e-02
# [FedAvg-Join] Round 186 | test_old_mean=5.9186e-02 | test_new=5.6037e-02
# [FedAvg-Join] Round 187 | test_old_mean=5.8472e-02 | test_new=5.5512e-02
# [FedAvg-Join] Round 188 | test_old_mean=5.7775e-02 | test_new=5.4992e-02
# [FedAvg-Join] Round 189 | test_old_mean=5.7118e-02 | test_new=5.4509e-02
# [FedAvg-Join] Round 190 | test_old_mean=5.6478e-02 | test_new=5.4043e-02
# [FedAvg-Join] Round 191 | test_old_mean=5.5856e-02 | test_new=5.3579e-02
# [FedAvg-Join] Round 192 | test_old_mean=5.5265e-02 | test_new=5.3142e-02
# [FedAvg-Join] Round 193 | test_old_mean=5.4702e-02 | test_new=5.2716e-02
# [FedAvg-Join] Round 194 | test_old_mean=5.4152e-02 | test_new=5.2285e-02
# [FedAvg-Join] Round 195 | test_old_mean=5.3651e-02 | test_new=5.1886e-02
# [FedAvg-Join] Round 196 | test_old_mean=5.3175e-02 | test_new=5.1498e-02
# [FedAvg-Join] Round 197 | test_old_mean=5.2708e-02 | test_new=5.1114e-02
# [FedAvg-Join] Round 198 | test_old_mean=5.2254e-02 | test_new=5.0740e-02
# [FedAvg-Join] Round 199 | test_old_mean=5.1810e-02 | test_new=5.0368e-02
# [FedAvg-Join] Round 200 | test_old_mean=5.1419e-02 | test_new=5.0036e-02

# %% [markdown]
# Stability: hệ thống FL ổn định, không phá old clients khi có client mới join.
#
# Benefit for newcomer: client mới được lợi khi tham gia FL (test MSE thấp hơn zero-shot).
# Adding a new client does not harm existing clients, and can even slightly improve their performance.

# %%
# %run -i plot_scenario_b.py
# Out:
# Evaluating per-client test MSE for Join vs NoJoin ...
# Final per-client test MSE (NoJoin -> Join):
#   gfli1_test_impedance_dataset: 6.8241e-02 -> 5.0036e-02 (impr +26.68% )
#   gfli2_test_impedance_dataset: 7.6955e-02 -> 6.0517e-02 (impr +21.36% )
#   gfli3_test_impedance_dataset: 6.7860e-02 -> 4.7783e-02 (impr +29.59% )
#   gfli4_test_impedance_dataset: 8.6241e-02 -> 5.6885e-02 (impr +34.04% )
#   gfli5_test_impedance_dataset: 3.8803e-02 -> 3.2732e-02 (impr +15.65% )
#   gfli6_test_impedance_dataset: 6.1670e-02 -> 4.7754e-02 (impr +22.56% )
#   gfli7_test_impedance_dataset: 5.8648e-02 -> 4.3906e-02 (impr +25.14% )
#   gfli8_test_impedance_dataset: 9.3753e-02 -> 6.0110e-02 (impr +35.88% )
#   gfli9_test_impedance_dataset: 8.3299e-02 -> 6.1666e-02 (impr +25.97% )
# Jain fairness: NoJoin=0.9253, Join=0.9574
# C:\Users\ACER\OneDrive - Umich\My PhD\Research\Topic discussion\Impedance-based Stability Analysis\ML_basedIMEst\FL\CodeImplement\plot_scenario_b.py:215: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax5.boxplot(
# Summary:
#   Jain fairness -> NoJoin: 0.9253 | Join: 0.9574
#   Mean MSE -> NoJoin: 7.0608e-02 | Join: 5.1265e-02
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\OneDrive - Umich\My PhD\Research\Topic discussion\Impedance-based Stability Analysis\ML_basedIMEst\FL\CodeImplement\plot_scenario_b.py:246
#     244 print(f"  Jain fairness -> NoJoin: {jain_nojoin:.4f} | Join: {jain_join:.4f}")
#     245 print(f"  Mean MSE -> NoJoin: {np.mean(mse_nojoin):.4e} | Join: {np.mean(mse_join):.4e}")
# --> 246 best_clients = sorted(zip(client_order, improvements), key=lambda x: x[1], reverse=True)[:3]
#     247 print("  Top improvements (NoJoin -> Join):")
#     248 for name, imp in best_clients:
#
# NameError: name 'improvements' is not defined
